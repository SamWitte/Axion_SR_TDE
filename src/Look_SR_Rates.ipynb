# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

###########################
# Setup Plotting Defaults #
###########################
# For more options see https://matplotlib.org/users/customizing.html

# Commands for high detail plots (much larger in file size though)
#mpl.rcParams['agg.path.chunksize'] = 1000
#mpl.rcParams['savefig.dpi'] = 1000

# Line styles
mpl.rcParams['lines.linewidth'] = 1.5
mpl.rcParams['lines.antialiased'] = True
mpl.rcParams['lines.dashed_pattern'] = 2.8, 1.5
mpl.rcParams['lines.dashdot_pattern'] = 4.8, 1.5, 0.8, 1.5
mpl.rcParams['lines.dotted_pattern'] = 1.1, 1.1
mpl.rcParams['lines.scale_dashes'] = True

# Default colors
from cycler import cycler
mpl.rcParams['axes.prop_cycle'] = cycler('color',['cornflowerblue','forestgreen','maroon','goldenrod','firebrick','mediumorchid', 'navy', 'brown'])


# Fonts
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.serif'] = 'Helvetica'
mpl.rcParams['font.sans-serif'] = 'CMU Sans Serif, DejaVu Sans, Bitstream Vera Sans, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif'
mpl.rcParams['text.usetex'] = True

# Axes
mpl.rcParams['axes.linewidth'] = 1.0
mpl.rcParams['axes.labelsize'] = 24
mpl.rcParams['axes.labelpad'] = 10.0
                                                  
                                                  
# Tick marks - the essence of life
mpl.rcParams['xtick.top'] = True
mpl.rcParams['xtick.major.size'] = 10
mpl.rcParams['xtick.minor.size'] = 5
mpl.rcParams['xtick.major.width'] = 1.0
mpl.rcParams['xtick.minor.width'] = 0.75
mpl.rcParams['xtick.major.pad'] = 8
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['ytick.right'] = True
mpl.rcParams['ytick.major.size'] = 10
mpl.rcParams['ytick.minor.size'] = 5
mpl.rcParams['ytick.major.width'] = 1.0
mpl.rcParams['ytick.minor.width'] = 0.75
mpl.rcParams['ytick.major.pad'] = 8
mpl.rcParams['ytick.labelsize'] = 14
mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['ytick.minor.visible'] = True

# Legend
mpl.rcParams['legend.fontsize'] = 14
mpl.rcParams['legend.frameon'] = True
mpl.rcParams['legend.framealpha'] = 0.8
#mpl.rcParams['legend.edgecolor'] = 'black'
mpl.rcParams['legend.fancybox'] = True
mpl.rcParams['legend.borderpad'] = 0.4 # border whitespace
mpl.rcParams['legend.labelspacing'] = 0.5 # the vertical space between the legend entries
mpl.rcParams['legend.handlelength'] = 1.5 # the length of the legend lines
mpl.rcParams['legend.handleheight'] = 0.7 # the height of the legend handle
mpl.rcParams['legend.handletextpad'] = 0.5 # the space between the legend line and legend text
mpl.rcParams['legend.borderaxespad'] = 0.5 # the border between the axes and legend edge
mpl.rcParams['legend.columnspacing'] = 2.0 # column separation


# Figure size
#mpl.rcParams['figure.figsize'] = 10, 6

# Save details
mpl.rcParams['savefig.bbox'] = 'tight'
mpl.rcParams['savefig.pad_inches'] = 0.1

# %%
# spinL = [0.5, 0.58, 0.66, 0.74, 0.83, 0.91]

spinL = [0.5, 0.7, 0.9, 0.99]
# spinL = [0.7]
clist = ["#588B8B", "#C8553D", "#F28F3B", "#231F20", "#7EBDC2", "#BD8B9C"]
lww=0.9
for i in range(len(spinL)):
    Load211_det = np.loadtxt("test_store/211_det_spin_"+str(spinL[i])+"_test.dat")
    Load211_new = np.loadtxt("test_store/211_new_spin_"+str(spinL[i])+"_test.dat")


    plt.plot(Load211_det[:,0], Load211_det[:,1], lw=lww, c=clist[i])
    plt.plot(Load211_new[:,0], Load211_new[:,1], lw=lww, ls="--", c=clist[i])


#alph = np.logspace(np.log10(0.03), np.log10(.9), 100)
#plt.plot(alph, 4e-2 * alph**8 * (0.99 - 2 * alph * (1 + np.sqrt(1 - alph**2))) / 3e-10, "g")

plt.axvline(0.45, 0, 1)

plt.plot()
plt.yscale("log")
plt.xscale("log")
plt.xlim([0.03, 0.5])
plt.ylim([1e-8, 1e4])
# Out:
# (1e-08, 10000.0)

# %%
# spinL = [0.5, 0.58, 0.66, 0.74, 0.83, 0.91]

spinL = [0.5, 0.7, 0.9, 0.99]
# spinL = [0.7]
clist = ["#588B8B", "#C8553D", "#F28F3B", "#231F20", "#7EBDC2", "#BD8B9C"]
lww=0.9
for i in range(len(spinL)):
    Load211_det = np.loadtxt("test_store/411_det_spin_"+str(spinL[i])+"_test.dat")
    Load211_new = np.loadtxt("test_store/411_new_spin_"+str(spinL[i])+"_test.dat")


    plt.plot(Load211_det[:,0], Load211_det[:,1], lw=lww, c=clist[i])
    plt.plot(Load211_new[:,0], Load211_new[:,1], lw=lww, ls="--", c=clist[i])

plt.axvline(0.45, 0, 1)


plt.yscale("log")
plt.xscale("log")
plt.xlim([0.03, 0.5])
plt.ylim([1e-9, 1e4])
# Out:
# (1e-09, 10000.0)

# %%
# spinL = [0.5, 0.58, 0.66, 0.74, 0.83, 0.91]

spinL = [0.5, 0.7, 0.9, 0.99]
# spinL = [0.7]
clist = ["#588B8B", "#C8553D", "#F28F3B", "#231F20", "#7EBDC2", "#BD8B9C"]
lww=0.9
for i in range(len(spinL)):
    Load211_det = np.loadtxt("test_store/322_det_spin_"+str(spinL[i])+"_test.dat")
    Load211_new = np.loadtxt("test_store/322_new_spin_"+str(spinL[i])+"_test.dat")


    plt.plot(Load211_det[:,0], Load211_det[:,1], lw=lww, c=clist[i])
    plt.plot(Load211_new[:,0], Load211_new[:,1], lw=lww, ls="--", c=clist[i])

plt.axvline(0.94, 0, 1)

plt.yscale("log")
plt.xscale("log")
plt.xlim([0.03, 1.4])
plt.ylim([1e-14, 1e4])
# Out:
# (1e-14, 10000.0)

# %%
# spinL = [0.5, 0.58, 0.66, 0.74, 0.83, 0.91]

spinL = [0.5, 0.7, 0.9, 0.99]
# spinL = [0.7]
clist = ["#588B8B", "#C8553D", "#F28F3B", "#231F20", "#7EBDC2", "#BD8B9C"]
lww=0.9
for i in range(len(spinL)):
    Load211_det = np.loadtxt("test_store/422_det_spin_"+str(spinL[i])+"_test.dat")
    Load211_new = np.loadtxt("test_store/422_new_spin_"+str(spinL[i])+"_test.dat")


    plt.plot(Load211_det[:,0], Load211_det[:,1], lw=lww, c=clist[i])
    plt.plot(Load211_new[:,0], Load211_new[:,1], lw=lww, ls="--", c=clist[i])


plt.yscale("log")
plt.xscale("log")
plt.xlim([0.03, 1.4])
plt.ylim([1e-14, 1e4])
# Out:
# (1e-14, 10000.0)

# %%
# spinL = [0.5, 0.58, 0.66, 0.74, 0.83, 0.91]

spinL = [0.5, 0.7, 0.9, 0.99]
# spinL = [0.7]
clist = ["#588B8B", "#C8553D", "#F28F3B", "#231F20", "#7EBDC2", "#BD8B9C"]
lww=0.9
for i in range(len(spinL)):
    Load211_det = np.loadtxt("test_store/433_det_spin_"+str(spinL[i])+"_test.dat")
    Load211_new = np.loadtxt("test_store/433_new_spin_"+str(spinL[i])+"_test.dat")


    plt.plot(Load211_det[:,0], Load211_det[:,1], lw=lww, c=clist[i])
    plt.plot(Load211_new[:,0], Load211_new[:,1], lw=lww, ls="--", c=clist[i])


plt.yscale("log")
plt.xscale("log")
plt.xlim([0.03, 2])
plt.ylim([1e-10, 1e6])
# Out:
# (1e-10, 1000000.0)

# %%
# spinL = [0.5, 0.58, 0.66, 0.74, 0.83, 0.91]

spinL = [0.5, 0.7, 0.9, 0.99]
# spinL = [0.7]
clist = ["#588B8B", "#C8553D", "#F28F3B", "#231F20", "#7EBDC2", "#BD8B9C"]
lww=0.9
for i in range(len(spinL)):
    Load211_det = np.loadtxt("test_store/511_det_spin_"+str(spinL[i])+"_test.dat")
    Load211_new = np.loadtxt("test_store/511_new_spin_"+str(spinL[i])+"_test.dat")


    plt.plot(Load211_det[:,0], Load211_det[:,1], lw=lww, c=clist[i])
    plt.plot(Load211_new[:,0], Load211_new[:,1], lw=lww, ls="--", c=clist[i])


plt.yscale("log")
plt.xscale("log")
plt.xlim([0.03, 1.4])
plt.ylim([1e-5, 1e4])
# Out:
# (1e-05, 10000.0)

# %%
# spinL = [0.5, 0.58, 0.66, 0.74, 0.83, 0.91]

spinL = [0.5,  0.99]
# spinL = [0.7]
clist = ["#588B8B", "#C8553D", "#F28F3B", "#231F20", "#7EBDC2", "#BD8B9C"]
lww=0.9
for i in range(len(spinL)):
    Load211_det = np.loadtxt("test_store/211_new_spin_"+str(spinL[i])+".dat")
    Load211_new = np.loadtxt("test_store/411_new_spin_"+str(spinL[i])+".dat")


    plt.plot(Load211_det[:,0], Load211_det[:,1], lw=lww, c=clist[i])
    plt.plot(Load211_new[:,0], 7 * Load211_new[:,1], lw=lww, ls="--", c=clist[i])


plt.yscale("log")
plt.xscale("log")
plt.xlim([0.03, 1.4])
plt.ylim([1e-6, 1e4])
# Out:
# (1e-06, 10000.0)

# %%
# spinL = [0.5, 0.58, 0.66, 0.74, 0.83, 0.91]

spinL = [0.5, 0.7, 0.9, 0.99]
# spinL = [0.7]
clist = ["#588B8B", "#C8553D", "#F28F3B", "#231F20", "#7EBDC2", "#BD8B9C"]
lww=0.9
for i in range(len(spinL)):
    Load211_det = np.loadtxt("test_store/211_new_spin_"+str(spinL[i])+".dat")
    Load211_new = np.loadtxt("test_store/211_new_spin_"+str(spinL[i])+"_test.dat")


    plt.plot(Load211_det[:,0], Load211_det[:,1], lw=lww, c=clist[i])
    plt.plot(Load211_new[:,0], Load211_new[:,1], lw=lww, ls="--", c=clist[i])


plt.yscale("log")
plt.xscale("log")
plt.xlim([0.03, 0.5])
plt.ylim([1e-5, 1e4])
# Out:
# (1e-05, 10000.0)

# %%
# spinL = [0.5, 0.58, 0.66, 0.74, 0.83, 0.91]

spinL = [0.5, 0.7, 0.9, 0.99]
# spinL = [0.7]
clist = ["#588B8B", "#C8553D", "#F28F3B", "#231F20", "#7EBDC2", "#BD8B9C"]
lww=0.9
for i in range(len(spinL)):
    Load211_det = np.loadtxt("test_store/322_new_spin_"+str(spinL[i])+".dat")
    Load211_new = np.loadtxt("test_store/322_new_spin_"+str(spinL[i])+"_test.dat")


    plt.plot(Load211_det[:,0], Load211_det[:,1], lw=lww, c=clist[i])
    plt.plot(Load211_new[:,0], Load211_new[:,1], lw=lww, ls="--", c=clist[i])


plt.yscale("log")
plt.xscale("log")
plt.xlim([0.1, 1.4])
plt.ylim([1e-13, 1e4])
# Out:
# (1e-13, 10000.0)

# %%
# spinL = [0.5, 0.58, 0.66, 0.74, 0.83, 0.91]

spinL = [0.5, 0.7, 0.9, 0.99]
# spinL = [0.9, 0.99]
# spinL = [0.7]
clist = ["#588B8B", "#C8553D", "#F28F3B", "#231F20", "#7EBDC2", "#BD8B9C"]
lww=0.9
for i in range(len(spinL)):
    Load211_det = np.loadtxt("test_store/422_det_spin_"+str(spinL[i])+"_test.dat")
    Load211_new = np.loadtxt("test_store/422_new_spin_"+str(spinL[i])+"_test.dat")


    plt.plot(Load211_det[:,0], Load211_det[:,1], lw=lww, c=clist[i])
    plt.plot(Load211_new[:,0], Load211_new[:,1], lw=lww, ls="--", c=clist[i])


plt.yscale("log")
plt.xscale("log")
plt.xlim([0.01, 1.4])
plt.ylim([1e-18, 1e4])
# Out:
# (1e-18, 10000.0)

# %%
# spinL = [0.5, 0.58, 0.66, 0.74, 0.83, 0.91]

spinL = [0.5, 0.7, 0.9, 0.99]
# spinL = [0.7]
clist = ["#588B8B", "#C8553D", "#F28F3B", "#231F20", "#7EBDC2", "#BD8B9C"]
lww=0.9
for i in range(len(spinL)):
    Load211_det = np.loadtxt("test_store/433_det_spin_"+str(spinL[i])+"_test.dat")
    Load211_new = np.loadtxt("test_store/433_new_spin_"+str(spinL[i])+"_test.dat")


    plt.plot(Load211_det[:,0], Load211_det[:,1], lw=lww, c=clist[i])
    plt.plot(Load211_new[:,0], Load211_new[:,1], lw=lww, ls="--", c=clist[i])


plt.yscale("log")
plt.xscale("log")
plt.xlim([0.01, 1.4])
plt.ylim([1e-30, 1e4])
# Out:
# (1e-30, 10000.0)

# %%
(1e-6 * 1e-12 / 6.58e-16)**-1
# Out:
# 658.0000000000001

# %%
look at levels i havent included.

# %%
# spinL = [0.5, 0.58, 0.66, 0.74, 0.83, 0.91]

spinL = [0.99]
# spinL = [0.7]
clist = ["#588B8B", "#C8553D", "#F28F3B", "#231F20", "#7EBDC2", "#BD8B9C"]
lww=0.9
for i in range(len(spinL)):

    Load211_new = np.loadtxt("test_store/211_new_spin_"+str(spinL[i])+"_test.dat")
    Load311_new = np.loadtxt("test_store/311_new_spin_"+str(spinL[i])+"_test.dat")
    Load411_new = np.loadtxt("test_store/411_new_spin_"+str(spinL[i])+"_test.dat")
    
    plt.plot(Load211_new[:,0], Load211_new[:,1], lw=lww, c=clist[0])
    plt.plot(Load311_new[:,0], Load311_new[:,1], lw=lww, ls="--", c=clist[1])
    plt.plot(Load411_new[:,0], Load411_new[:,1], lw=lww, ls="--", c=clist[2])
    
    Load322_new = np.loadtxt("test_store/322_new_spin_"+str(spinL[i])+"_test.dat")
    Load321_new = np.loadtxt("test_store/321_new_spin_"+str(spinL[i])+"_test.dat")
    Load421_new = np.loadtxt("test_store/421_new_spin_"+str(spinL[i])+"_test.dat")
    Load431_new = np.loadtxt("test_store/431_new_spin_"+str(spinL[i])+"_test.dat")
    
#     # plt.plot(Load322_new[:,0], Load322_new[:,1], lw=lww, ls="--", c=clist[0]) 
    plt.plot(Load321_new[:,0], Load321_new[:,1], lw=lww, ls="dotted", c=clist[1])
    plt.plot(Load421_new[:,0], Load421_new[:,1], lw=lww, ls="dotted", c=clist[2])
    plt.plot(Load431_new[:,0], Load431_new[:,1], lw=lww, ls="dotted", c=clist[3])
    
#     Load433_new = np.loadtxt("test_store/433_new_spin_"+str(spinL[i])+"_test.dat")
#     Load432_new = np.loadtxt("test_store/432_new_spin_"+str(spinL[i])+"_test.dat")
    plt.plot(Load433_new[:,0], Load433_new[:,1], lw=lww, c=clist[0])
    plt.plot(Load432_new[:,0], Load432_new[:,1], lw=lww, ls="--", c=clist[1])


#alph = np.logspace(np.log10(0.03), np.log10(.9), 100)
#plt.plot(alph, 4e-2 * alph**8 * (0.99 - 2 * alph * (1 + np.sqrt(1 - alph**2))) / 3e-10, "g")

plt.plot()
plt.yscale("log")
plt.xscale("log")
plt.xlim([0.03, 1])
plt.ylim([1e-12, 1e4])
# Out:
# (1e-12, 10000.0)

# %%
# spinL = [0.5, 0.58, 0.66, 0.74, 0.83, 0.91]

spinL = [0.99]
# spinL = [0.7]
clist = ["#588B8B", "#C8553D", "#F28F3B", "#231F20", "#7EBDC2", "#BD8B9C"]
lww=0.9
for i in range(len(spinL)):

    
    Load322_new = np.loadtxt("test_store/322_new_spin_"+str(spinL[i])+"_test.dat")
    Load321_new = np.loadtxt("test_store/321_new_spin_"+str(spinL[i])+"_test.dat")
    Load421_new = np.loadtxt("test_store/421_new_spin_"+str(spinL[i])+"_test.dat")
    Load431_new = np.loadtxt("test_store/431_new_spin_"+str(spinL[i])+"_test.dat")
    
    # plt.plot(Load322_new[:,0], Load322_new[:,1], lw=lww, ls="--", c=clist[0])
    plt.plot(Load321_new[:,0], Load321_new[:,1], lw=lww, ls="dotted", c=clist[1])
    plt.plot(Load421_new[:,0], Load421_new[:,1], lw=lww, ls="dotted", c=clist[2])
    plt.plot(Load431_new[:,0], Load431_new[:,1], lw=lww, ls="dotted", c=clist[3])
    
    Load433_new = np.loadtxt("test_store/433_new_spin_"+str(spinL[i])+"_test.dat")
    Load432_new = np.loadtxt("test_store/432_new_spin_"+str(spinL[i])+"_test.dat")
    plt.plot(Load433_new[:,0], Load433_new[:,1], lw=1.5, c=clist[0])
    plt.plot(Load432_new[:,0], Load432_new[:,1], lw=lww, ls="dotted", c=clist[1])


#alph = np.logspace(np.log10(0.03), np.log10(.9), 100)
#plt.plot(alph, 4e-2 * alph**8 * (0.99 - 2 * alph * (1 + np.sqrt(1 - alph**2))) / 3e-10, "g")

plt.plot()
plt.yscale("log")
plt.xscale("log")
plt.xlim([0.03, 1])
plt.ylim([1e-10, 1e1])
# Out:
# (1e-10, 10.0)
