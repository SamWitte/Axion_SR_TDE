# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

###########################
# Setup Plotting Defaults #
###########################
# For more options see https://matplotlib.org/users/customizing.html

# Commands for high detail plots (much larger in file size though)
#mpl.rcParams['agg.path.chunksize'] = 1000
#mpl.rcParams['savefig.dpi'] = 1000

# Line styles
mpl.rcParams['lines.linewidth'] = 1.5
mpl.rcParams['lines.antialiased'] = True
mpl.rcParams['lines.dashed_pattern'] = 2.8, 1.5
mpl.rcParams['lines.dashdot_pattern'] = 4.8, 1.5, 0.8, 1.5
mpl.rcParams['lines.dotted_pattern'] = 1.1, 1.1
mpl.rcParams['lines.scale_dashes'] = True

# Default colors
from cycler import cycler
mpl.rcParams['axes.prop_cycle'] = cycler('color',['cornflowerblue','forestgreen','maroon','goldenrod','firebrick','mediumorchid', 'navy', 'brown'])


# Fonts
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.serif'] = 'Helvetica'
mpl.rcParams['font.sans-serif'] = 'CMU Sans Serif, DejaVu Sans, Bitstream Vera Sans, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif'
mpl.rcParams['text.usetex'] = True

# Axes
mpl.rcParams['axes.linewidth'] = 1.0
mpl.rcParams['axes.labelsize'] = 24
mpl.rcParams['axes.labelpad'] = 10.0
                                                  
                                                  
# Tick marks - the essence of life
mpl.rcParams['xtick.top'] = True
mpl.rcParams['xtick.major.size'] = 10
mpl.rcParams['xtick.minor.size'] = 5
mpl.rcParams['xtick.major.width'] = 1.0
mpl.rcParams['xtick.minor.width'] = 0.75
mpl.rcParams['xtick.major.pad'] = 8
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['ytick.right'] = True
mpl.rcParams['ytick.major.size'] = 10
mpl.rcParams['ytick.minor.size'] = 5
mpl.rcParams['ytick.major.width'] = 1.0
mpl.rcParams['ytick.minor.width'] = 0.75
mpl.rcParams['ytick.major.pad'] = 8
mpl.rcParams['ytick.labelsize'] = 14
mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['ytick.minor.visible'] = True

# Legend
mpl.rcParams['legend.fontsize'] = 14
mpl.rcParams['legend.frameon'] = True
mpl.rcParams['legend.framealpha'] = 0.8
#mpl.rcParams['legend.edgecolor'] = 'black'
mpl.rcParams['legend.fancybox'] = True
mpl.rcParams['legend.borderpad'] = 0.4 # border whitespace
mpl.rcParams['legend.labelspacing'] = 0.5 # the vertical space between the legend entries
mpl.rcParams['legend.handlelength'] = 1.5 # the length of the legend lines
mpl.rcParams['legend.handleheight'] = 0.7 # the height of the legend handle
mpl.rcParams['legend.handletextpad'] = 0.5 # the space between the legend line and legend text
mpl.rcParams['legend.borderaxespad'] = 0.5 # the border between the axes and legend edge
mpl.rcParams['legend.columnspacing'] = 2.0 # column separation


# Figure size
#mpl.rcParams['figure.figsize'] = 10, 6

# Save details
mpl.rcParams['savefig.bbox'] = 'tight'
mpl.rcParams['savefig.pad_inches'] = 0.1

# %%
r1 = np.loadtxt("../test_store/tt1.dat")
r2 = np.loadtxt("../test_store/test2.dat")
r3 = np.loadtxt("../test_store/test3.dat")
rout = np.loadtxt("../test_store/test_1.dat")
plt.plot(r1[:,0], r1[:,1], "r")
plt.plot(r2[:,0], r2[:,1], "b")
plt.plot(r3[:,0], r3[:,1], "k")

plt.plot(rout[:,0], rout[:,1], "g")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-120,1e-2])
plt.xlim([1,1e7])
# Out:
# (1, 10000000.0)

# %%
r2
# Out:
# array([[1.31356215e+00, 3.46976332e-44],
#        [1.32880386e+00, 3.63379255e-44],
#        [1.34422243e+00, 3.80526125e-44],
#        ...,
#        [1.29920119e+05, 4.68956009e-58],
#        [1.31427627e+05, 2.00184646e-58],
#        [1.32952627e+05, 8.38689714e-59]])

# %%
r1 = np.loadtxt("../test_store/RadTest_LowA_1_n_2_l_1_m_1_.dat")
r2 = np.loadtxt("../test_store/RadTest_LowA_2_n_2_l_1_m_1_.dat")
r3 = np.loadtxt("../test_store/RadTest_LowA_2v2_n_2_l_1_m_1_.dat")

r1_2 = np.loadtxt("../test_store/RadTest_HighA_1_n_2_l_1_m_1_.dat")
r2_2 = np.loadtxt("../test_store/RadTest_HighA_2_n_2_l_1_m_1_.dat")
r3_2 = np.loadtxt("../test_store/RadTest_HighA_2v2_n_2_l_1_m_1_.dat")


plt.plot(r1[:,0], r1[:,1], "r")
plt.plot(r2[:,0], r2[:,1], "g")
plt.plot(r3[:,0], r3[:,1], "k", ls="dotted")

plt.plot(r1_2[:,0], r1_2[:,1], "r")
plt.plot(r2_2[:,0], r2_2[:,1], "g", ls="dashed")
plt.plot(r3_2[:,0], r3_2[:,1], "k", ls="dotted")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-19,1])
plt.xlim([1,1e7])
# Out:
# (1, 10000000.0)

# %%
r1 = np.loadtxt("../test_store/RadTest_LowA_1_n_3_l_1_m_1_.dat")
r2 = np.loadtxt("../test_store/RadTest_LowA_2_n_3_l_1_m_1_.dat")
r3 = np.loadtxt("../test_store/RadTest_LowA_2v2_n_3_l_1_m_1_.dat")

r1_2 = np.loadtxt("../test_store/RadTest_HighA_1_n_3_l_1_m_1_.dat")
r2_2 = np.loadtxt("../test_store/RadTest_HighA_2_n_3_l_1_m_1_.dat")
r3_2 = np.loadtxt("../test_store/RadTest_HighA_2v2_n_3_l_1_m_1_.dat")

plt.plot(r1[:,0], r1[:,1], "r")
plt.plot(r2[:,0], r2[:,1], "g")
plt.plot(r3[:,0], r3[:,1], "k")

plt.plot(r1_2[:,0], r1_2[:,1], "r")
plt.plot(r2_2[:,0], r2_2[:,1], "g")
plt.plot(r3_2[:,0], r3_2[:,1], "k")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-19,1])
plt.xlim([1,1e5])
# Out:
# (1, 100000.0)

# %%
r1 = np.loadtxt("../test_store/RadTest_LowA_1_n_4_l_1_m_1_.dat")
r2 = np.loadtxt("../test_store/RadTest_LowA_2_n_4_l_1_m_1_.dat")
r3 = np.loadtxt("../test_store/RadTest_LowA_2v2_n_4_l_1_m_1_.dat")

r1_2 = np.loadtxt("../test_store/RadTest_HighA_1_n_4_l_1_m_1_.dat")
r2_2 = np.loadtxt("../test_store/RadTest_HighA_2_n_4_l_1_m_1_.dat")
r3_2 = np.loadtxt("../test_store/RadTest_HighA_2v2_n_4_l_1_m_1_.dat")

plt.plot(r1[:,0], r1[:,1], "r")
plt.plot(r2[:,0], r2[:,1], "g")
plt.plot(r3[:,0], r3[:,1], "k")

plt.plot(r1_2[:,0], r1_2[:,1], "r")
plt.plot(r2_2[:,0], r2_2[:,1], "g")
plt.plot(r3_2[:,0], r3_2[:,1], "k")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-19,1])
plt.xlim([1,1e6])
# Out:
# (1, 1000000.0)

# %%
r1 = np.loadtxt("../test_store/RadTest_LowA_1_n_5_l_1_m_1_.dat")
r2 = np.loadtxt("../test_store/RadTest_LowA_2_n_5_l_1_m_1_.dat")
r3 = np.loadtxt("../test_store/RadTest_LowA_2v2_n_5_l_1_m_1_.dat")

r1_2 = np.loadtxt("../test_store/RadTest_HighA_1_n_5_l_1_m_1_.dat")
r2_2 = np.loadtxt("../test_store/RadTest_HighA_2_n_5_l_1_m_1_.dat")
r3_2 = np.loadtxt("../test_store/RadTest_HighA_2v2_n_5_l_1_m_1_.dat")

plt.plot(r1[:,0], r1[:,1], "r")
plt.plot(r2[:,0], r2[:,1], "g")
plt.plot(r3[:,0], r3[:,1], "k")

plt.plot(r1_2[:,0], r1_2[:,1], "r")
plt.plot(r2_2[:,0], r2_2[:,1], "g")
plt.plot(r3_2[:,0], r3_2[:,1], "k")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-19,1])
plt.xlim([1,1e6])
# Out:
# (1, 1000000.0)

# %%
r1 = np.loadtxt("../test_store/RadTest_LowA_1_n_3_l_2_m_2_.dat")
r2 = np.loadtxt("../test_store/RadTest_LowA_2_n_3_l_2_m_2_.dat")
r3 = np.loadtxt("../test_store/RadTest_LowA_2v2_n_3_l_2_m_2_.dat")

r1_2 = np.loadtxt("../test_store/RadTest_HighA_1_n_3_l_2_m_2_.dat")
r2_2 = np.loadtxt("../test_store/RadTest_HighA_2_n_3_l_2_m_2_.dat")
r3_2 = np.loadtxt("../test_store/RadTest_HighA_2v2_n_3_l_2_m_2_.dat")

plt.plot(r1[:,0], r1[:,1], "r")
plt.plot(r2[:,0], r2[:,1], "g")
plt.plot(r3[:,0], r3[:,1], "k", ls="--")

plt.plot(r1_2[:,0], r1_2[:,1], "r")
plt.plot(r2_2[:,0], r2_2[:,1], "g")
plt.plot(r3_2[:,0], r3_2[:,1], "k",  ls="--")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-23,1])
plt.xlim([1,1e6])
# Out:
# (1, 1000000.0)

# %%
r1 = np.loadtxt("../test_store/RadTest_LowA_1_n_4_l_2_m_2_.dat")
r2 = np.loadtxt("../test_store/RadTest_LowA_2_n_4_l_2_m_2_.dat")
r3 = np.loadtxt("../test_store/RadTest_LowA_2v2_n_4_l_2_m_2_.dat")

r1_2 = np.loadtxt("../test_store/RadTest_HighA_1_n_4_l_2_m_2_.dat")
r2_2 = np.loadtxt("../test_store/RadTest_HighA_2_n_4_l_2_m_2_.dat")
r3_2 = np.loadtxt("../test_store/RadTest_HighA_2v2_n_4_l_2_m_2_.dat")

plt.plot(r1[:,0], r1[:,1], "r")
plt.plot(r2[:,0], r2[:,1], "g")
plt.plot(r3[:,0], r3[:,1], "k", ls="--")

plt.plot(r1_2[:,0], r1_2[:,1], "r")
plt.plot(r2_2[:,0], r2_2[:,1], "g")
plt.plot(r3_2[:,0], r3_2[:,1], "k",  ls="--")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-23,1])
plt.xlim([1,1e6])
# Out:
# (1, 1000000.0)

# %%
r1 = np.loadtxt("../test_store/RadTest_LowA_1_n_5_l_2_m_2_.dat")
r2 = np.loadtxt("../test_store/RadTest_LowA_2_n_5_l_2_m_2_.dat")
r3 = np.loadtxt("../test_store/RadTest_LowA_2v2_n_5_l_2_m_2_.dat")

r1_2 = np.loadtxt("../test_store/RadTest_HighA_1_n_5_l_2_m_2_.dat")
r2_2 = np.loadtxt("../test_store/RadTest_HighA_2_n_5_l_2_m_2_.dat")
r3_2 = np.loadtxt("../test_store/RadTest_HighA_2v2_n_5_l_2_m_2_.dat")

plt.plot(r1[:,0], r1[:,1], "r")
plt.plot(r2[:,0], r2[:,1], "g")
plt.plot(r3[:,0], r3[:,1], "k", ls="--")

plt.plot(r1_2[:,0], r1_2[:,1], "r")
plt.plot(r2_2[:,0], r2_2[:,1], "g")
plt.plot(r3_2[:,0], r3_2[:,1], "k",  ls="--")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-23,1])
plt.xlim([1,1e6])
# Out:
# (1, 1000000.0)

# %%
e1_r = np.loadtxt("../test_store/ErgEvol_n_2_l_1_m_1_.dat")
e1_i = np.loadtxt("../test_store/ErgEvol_I_n_2_l_1_m_1_.dat")
e1_r_c=np.loadtxt("../test_store/ErgEvol_Cheb_n_2_l_1_m_1_.dat")
e1_i_c=np.loadtxt("../test_store/ErgEvol_Cheb_I_n_2_l_1_m_1_.dat")


e3_r = np.loadtxt("../test_store/ErgEvol_n_3_l_1_m_1_.dat")
e3_i = np.loadtxt("../test_store/ErgEvol_I_n_3_l_1_m_1_.dat")
e3_r_c=np.loadtxt("../test_store/ErgEvol_Cheb_n_3_l_1_m_1_.dat")
e3_i_c=np.loadtxt("../test_store/ErgEvol_Cheb_I_n_3_l_1_m_1_.dat")

e5_r = np.loadtxt("../test_store/ErgEvol_n_5_l_1_m_1_.dat")
e5_i = np.loadtxt("../test_store/ErgEvol_I_n_5_l_1_m_1_.dat")
e5_r_c=np.loadtxt("../test_store/ErgEvol_Cheb_n_5_l_1_m_1_.dat")
e5_i_c=np.loadtxt("../test_store/ErgEvol_Cheb_I_n_5_l_1_m_1_.dat")

e32_r = np.loadtxt("../test_store/ErgEvol_n_3_l_2_m_2_.dat")
e32_i = np.loadtxt("../test_store/ErgEvol_I_n_3_l_2_m_2_.dat")
e32_r_c=np.loadtxt("../test_store/ErgEvol_Cheb_n_3_l_2_m_2_.dat")
e32_i_c=np.loadtxt("../test_store/ErgEvol_Cheb_I_n_3_l_2_m_2_.dat")

e52_i = np.loadtxt("../test_store/ErgEvol_I_n_5_l_2_m_2_.dat")
e52_i_c=np.loadtxt("../test_store/ErgEvol_Cheb_I_n_5_l_2_m_2_.dat")

e1_r = e1_r[e1_r[:,1] != 0.0, :]
e1_i = e1_i[e1_i[:,1] != 0.0, :]
e3_r = e3_r[e3_r[:,1] != 0.0, :]
e3_i = e3_i[e3_i[:,1] != 0.0, :]

e5_r = e5_r[e5_r[:,1] != 0.0, :]
e5_i = e5_i[e5_i[:,1] != 0.0, :]

e32_r = e32_r[e32_r[:,1] != 0.0, :]
e32_i = e32_i[e32_i[:,1] != 0.0, :]
e52_i = e52_i[e52_i[:,1] != 0.0, :]

# %%
plt.plot(e1_i[:,0], (e1_i[:,1]), lw=3, c="k")
plt.plot(e1_i_c[:,0], (e1_i_c[:,1]), ls="dashed", c="r", lw=2)

plt.plot(e3_i[:,0], (e3_i[:,1]), lw=3, c="k")
plt.plot(e3_i_c[:,0], (e3_i_c[:,1]), ls="dashed", c="r", lw=2)

plt.plot(e5_i[:,0], (e5_i[:,1]), lw=3, c="k")
plt.plot(e5_i_c[:,0], (e5_i_c[:,1]), ls="dashed", c="r", lw=2)

plt.plot(e32_i[:,0], (e32_i[:,1]), lw=3, c="k")
plt.plot(e32_i_c[:,0], (e32_i_c[:,1]), ls="dashed", c="r", lw=2)

plt.plot(e52_i[:,0], (e52_i[:,1]), lw=3, c="k")
plt.plot(e52_i_c[:,0], (e52_i_c[:,1]), ls="dashed", c="r", lw=2)

plt.yscale("log")
plt.xscale("log")

# %%
e52_i_c
# Out:
# array([[ 3.00000000e-02,  4.55464141e-25],
#        [ 8.10526316e-02,  1.14294083e-19],
#        [ 1.32105263e-01,  4.21889178e-17],
#        [ 1.83157895e-01,  1.97205377e-15],
#        [ 2.34210526e-01,  3.31524354e-14],
#        [ 2.85263158e-01,  3.03032897e-13],
#        [ 3.36315789e-01,  1.85003276e-12],
#        [ 3.87368421e-01, -2.51719652e-05],
#        [ 4.38421053e-01,  3.13788267e-11],
#        [ 4.89473684e-01,  6.14379959e-11],
#        [ 5.40526316e-01,  2.64026103e-10],
#        [ 5.91578947e-01,  5.39461470e-10],
#        [ 6.42631579e-01, -7.45360993e-10],
#        [ 6.93684211e-01, -3.29544036e-08],
#        [ 7.44736842e-01, -5.26288109e-07],
#        [ 7.95789474e-01, -5.49858788e-06],
#        [ 8.46842105e-01, -6.69237385e-05],
#        [ 8.97894737e-01, -4.89965511e-04],
#        [ 9.48947368e-01, -1.63297047e-03],
#        [ 1.00000000e+00, -2.20421498e-03]])
