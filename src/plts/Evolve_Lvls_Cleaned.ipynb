# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

###########################
# Setup Plotting Defaults #
###########################
# For more options see https://matplotlib.org/users/customizing.html

# Commands for high detail plots (much larger in file size though)
#mpl.rcParams['agg.path.chunksize'] = 1000
#mpl.rcParams['savefig.dpi'] = 1000

# Line styles
mpl.rcParams['lines.linewidth'] = 1.5
mpl.rcParams['lines.antialiased'] = True
mpl.rcParams['lines.dashed_pattern'] = 2.8, 1.5
mpl.rcParams['lines.dashdot_pattern'] = 4.8, 1.5, 0.8, 1.5
mpl.rcParams['lines.dotted_pattern'] = 1.1, 1.1
mpl.rcParams['lines.scale_dashes'] = True

# Default colors
from cycler import cycler
mpl.rcParams['axes.prop_cycle'] = cycler('color',['cornflowerblue','forestgreen','maroon','goldenrod','firebrick','mediumorchid', 'navy', 'brown'])


# Fonts
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.serif'] = 'Helvetica'
mpl.rcParams['font.sans-serif'] = 'CMU Sans Serif, DejaVu Sans, Bitstream Vera Sans, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif'
mpl.rcParams['text.usetex'] = True

# Axes
mpl.rcParams['axes.linewidth'] = 1.0
mpl.rcParams['axes.labelsize'] = 24
mpl.rcParams['axes.labelpad'] = 10.0
                                                  
                                                  
# Tick marks - the essence of life
mpl.rcParams['xtick.top'] = True
mpl.rcParams['xtick.major.size'] = 10
mpl.rcParams['xtick.minor.size'] = 5
mpl.rcParams['xtick.major.width'] = 1.0
mpl.rcParams['xtick.minor.width'] = 0.75
mpl.rcParams['xtick.major.pad'] = 8
mpl.rcParams['xtick.labelsize'] = 16
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['ytick.right'] = True
mpl.rcParams['ytick.major.size'] = 10
mpl.rcParams['ytick.minor.size'] = 5
mpl.rcParams['ytick.major.width'] = 1.0
mpl.rcParams['ytick.minor.width'] = 0.75
mpl.rcParams['ytick.major.pad'] = 8
mpl.rcParams['ytick.labelsize'] = 16
mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['ytick.minor.visible'] = True

# Legend
mpl.rcParams['legend.fontsize'] = 14
mpl.rcParams['legend.frameon'] = True
mpl.rcParams['legend.framealpha'] = 0.8
#mpl.rcParams['legend.edgecolor'] = 'black'
mpl.rcParams['legend.fancybox'] = True
mpl.rcParams['legend.borderpad'] = 0.4 # border whitespace
mpl.rcParams['legend.labelspacing'] = 0.5 # the vertical space between the legend entries
mpl.rcParams['legend.handlelength'] = 1.5 # the length of the legend lines
mpl.rcParams['legend.handleheight'] = 0.7 # the height of the legend handle
mpl.rcParams['legend.handletextpad'] = 0.5 # the space between the legend line and legend text
mpl.rcParams['legend.borderaxespad'] = 0.5 # the border between the axes and legend edge
mpl.rcParams['legend.columnspacing'] = 2.0 # column separation


# Figure size
#mpl.rcParams['figure.figsize'] = 10, 6

# Save details
# mpl.rcParams['savefig.bbox'] = 'tight'
# mpl.rcParams['savefig.pad_inches'] = 0.1
mpl.rcParams.update({'figure.autolayout': False})

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e18_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=65.44974
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e8])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-15, r"$f_a = 10^{18} \, {\rm GeV}$", fontsize=18);

axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
axs[1].text(2e-2, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
axs[1].text(2e-2, 10**-12, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
axs[1].text(2e-2, 10**-15, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
axs[1].text(2e-1, 10**-6, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
axs[1].text(2e-1, 10**-9, r"$\epsilon_{511}$", fontsize=22, c="#393A10");
axs[1].text(2e-1, 10**-12, r"$\epsilon_{522}$", fontsize=22, c="#F2A47D");
axs[1].text(2e-1, 10**-15, r"$\epsilon_{533}$", fontsize=22, c="#8A7198");
axs[1].text(2, 10**-15, r"$\epsilon_{544}$", fontsize=22, c="#ED6E7D");


plt.savefig("Solve_f18_eg1.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e16_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")


fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=65.44974 / (1e2)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e1])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-16, r"$f_a = 10^{16} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 7e-9, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))

plt.savefig("Solve_f16_eg1.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e14_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")

fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)

axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=65.44974 / (1e4)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e-3])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);

axs[1].text(1e4, 1e-16, r"$f_a = 10^{14} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 7e-9, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))

plt.savefig("Solve_f14_eg1.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e12_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")

fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=65.44974 / (1e6)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e-8])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
# axs[1].text(1e4, 5e-14, r"$\alpha = 0.33$", fontsize=18);
axs[1].text(1e4, 1e-17, r"$f_a = 10^{12} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 7e-9, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))

# fig.set_tight_layout(True)

plt.savefig("Solve_f12_eg1.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e12_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")

fig, axs = plt.subplots(2, sharex=False,  figsize=(10,6), gridspec_kw={'hspace': 0.2, 'height_ratios': [1, 1]})

lww=1.3
axs[0].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[0].plot(fa12[:,0], fa12[:,2], "#031D44", lw=lww)
axs[0].plot(fa12[:,0], fa12[:,3], "#00A676", lw=lww)
axs[0].plot(fa12[:,0], fa12[:,4], "#B68F40", lw=lww)
axs[0].plot(fa12[:,0], fa12[:,5], "#6DAEDB", lw=lww)
axs[0].plot(fa12[:,0], fa12[:,6], "#393A10", lw=lww)
axs[0].plot(fa12[:,0], fa12[:,7], "#F2A47D", lw=lww)
axs[0].plot(fa12[:,0], fa12[:,8], "#8A7198", lw=lww)

lww=1.3
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,2], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#8A7198", lw=lww)




BN211=65.44974 / (1e6)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)

axs[0].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[0].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[0].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[0].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[0].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[0].set_yscale("log")
axs[1].set_yscale("log")

axs[0].set_xscale("linear")
axs[1].set_xscale("linear")

axs[0].set_ylim([1e-17,1e-7])
axs[1].set_ylim([1e-17,1e-7])
axs[0].set_xlim([0.1,.26])
axs[1].set_xlim([5e-1,0.65])


axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[0].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23, labelpad=5);

fig.set_tight_layout(True)

plt.savefig("Solve_f12_crazy_zoom.jpeg", dpi=200, bbox_inches='tight')
# Out:
# /var/folders/2g/0h7xb5296_l51vyp88_ldzm80000gn/T/ipykernel_76455/863406937.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig("Solve_f12_crazy_zoom.jpeg", dpi=200, bbox_inches='tight')
# /var/folders/2g/0h7xb5296_l51vyp88_ldzm80000gn/T/ipykernel_76455/863406937.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig("Solve_f12_crazy_zoom.jpeg", dpi=200, bbox_inches='tight')
# /Users/samuelwitte/anaconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_FullRel_fa_1.0e12_ma_1.0e-12_MBH_22.2_spin_0.99_v2_.dat")
f12_NR = np.loadtxt("../test_store/OutRun_Lvln4_NonRel_fa_1.0e12_ma_1.0e-12_MBH_22.2_spin_0.99_v2_.dat")


fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})
# fig.subplots_adjust(bottom=0.15)

lww=0.8

axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#031D44", lw=lww, dashes=[4, 4])
axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#00A676", lw=lww,  dashes=[4, 4])
axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#B68F40", lw=lww, dashes=[4, 4])
axs[1].plot(f12_NR[:,0], f12_NR[:,6], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "#393A10", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "#F2A47D", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,9], "#8A7198", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,10], "#ED6E7D", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
# axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
# axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
# axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
# axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)
axs[0].plot(f12_NR[:,0], f12_NR[:,-2], "k", lw=lww, dashes=[4, 4])

BN211= 5.23597953858857e-10
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-17, 1e-7])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-1,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 4e-15, r"$\alpha = 0.17$", fontsize=18);
axs[1].text(1e4, 1e-16, r"$f_a = 10^{12} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 7e-9, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


axs[1].text(5e1, 10**-13.5, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
axs[1].text(5e1, 10**-14.5, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
axs[1].text(5e1, 10**-15.5, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
# axs[1].text(2e2, 10**-13.5, r"$\epsilon_{522}$", fontsize=22, c="#F2A47D");
# axs[1].text(2e2, 10**-14.5, r"$\epsilon_{533}$", fontsize=22, c="#8A7198");


# fig.set_tight_layout(True)

plt.savefig("Solve_f12_LowAlpha.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_FullRel_fa_1.0e16_ma_1.0e-12_MBH_22.2_spin_0.99_v2_.dat")
f12_NR = np.loadtxt("../test_store/OutRun_Lvln4_NonRel_fa_1.0e16_ma_1.0e-12_MBH_22.2_spin_0.99_v2_.dat")


fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})
# fig.subplots_adjust(bottom=0.15)

lww=0.8

axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#031D44", lw=lww, dashes=[4, 4])
axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#00A676", lw=lww,  dashes=[4, 4])
axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#B68F40", lw=lww, dashes=[4, 4])
axs[1].plot(f12_NR[:,0], f12_NR[:,6], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "#393A10", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "#F2A47D", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,9], "#8A7198", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,10], "#ED6E7D", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
# axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
# axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
# axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
# axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)
axs[0].plot(f12_NR[:,0], f12_NR[:,-2], "k", lw=lww, dashes=[4, 4])

BN211= 5.23597953858857e-10 * (1e4)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-14, 1e2])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-1,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 4e-10, r"$\alpha = 0.17$", fontsize=18);
axs[1].text(1e4, 1e-12, r"$f_a = 10^{16} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 7e-9, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


# axs[1].text(5e1, 10**-13.5, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
# axs[1].text(5e1, 10**-14.5, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
# axs[1].text(5e1, 10**-15.5, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
# axs[1].text(2e2, 10**-13.5, r"$\epsilon_{522}$", fontsize=22, c="#F2A47D");
# axs[1].text(2e2, 10**-14.5, r"$\epsilon_{533}$", fontsize=22, c="#8A7198");


# fig.set_tight_layout(True)

plt.savefig("Solve_f16_LowAlpha.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e18_ma_5.0e-12_MBH_22.2_spin_0.99_v2_.dat")

# %%
np.max(fa12[:,3])
# Out:
# 3.5450484054511433e-79

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e18_ma_5.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=5.23597953858857e-10 * (1e18/1e12)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e8])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-13, r"$\alpha = 0.83$", fontsize=18);
axs[1].text(1e4, 1e-16, r"$f_a = 10^{18} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
axs[1].text(2e-2, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
axs[1].text(2e-2, 10**-12, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
axs[1].text(2e-2, 10**-15, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
axs[1].text(2e-1, 10**-6, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
axs[1].text(2e-1, 10**-9, r"$\epsilon_{511}$", fontsize=22, c="#393A10");
axs[1].text(2e-1, 10**-12, r"$\epsilon_{522}$", fontsize=22, c="#F2A47D");
axs[1].text(2e-1, 10**-15, r"$\epsilon_{533}$", fontsize=22, c="#8A7198");
axs[1].text(2, 10**-15, r"$\epsilon_{544}$", fontsize=22, c="#ED6E7D");

plt.savefig("Solve_f18_eg2_alp_0831.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e12_ma_5.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)

axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=5.23597953858857e-10
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e-7])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-15, r"$\alpha = 0.83$", fontsize=18);
axs[1].text(1e4, 1e-16, r"$f_a = 10^{12} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


# axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
# axs[1].text(1e1, 10**-14, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
# axs[1].text(1e1, 10**-15, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
# axs[1].text(1e1, 10**-16, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
# axs[1].text(1e1, 10**-17, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
# axs[1].text(7e1, 10**-14, r"$\epsilon_{522}$", fontsize=22, c="#393A10");
# axs[1].text(7e1, 10**-15, r"$\epsilon_{533}$", fontsize=22, c="#F2A47D");
# axs[1].text(7e1, 10**-16, r"$\epsilon_{544}$", fontsize=22, c="#8A7198");


plt.savefig("Solve_f12_eg2_alp_0831.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e16_ma_5.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=5.23597953858857e-10 * (1e4)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e2])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-14, r"$\alpha = 0.83$", fontsize=18);
axs[1].text(1e4, 1e-16, r"$f_a = 10^{16} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


# axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
# axs[1].text(2e-2, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
# axs[1].text(2e-2, 10**-12, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
# axs[1].text(2e-2, 10**-15, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
# axs[1].text(2e-1, 10**-6, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
# axs[1].text(2e-1, 10**-9, r"$\epsilon_{522}$", fontsize=22, c="#393A10");
# axs[1].text(2e-1, 10**-12, r"$\epsilon_{533}$", fontsize=22, c="#F2A47D");
# axs[1].text(2e-1, 10**-15, r"$\epsilon_{544}$", fontsize=22, c="#8A7198");


plt.savefig("Solve_f16_eg2_alp_0831.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e14_ma_5.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=5.23597953858857e-10 * (1e2)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e-2])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-14, r"$\alpha = 0.83$", fontsize=18);
axs[1].text(1e4, 1e-16, r"$f_a = 10^{14} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


# axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
# axs[1].text(2e-2, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
# axs[1].text(2e-2, 10**-12, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
# axs[1].text(2e-2, 10**-15, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
# axs[1].text(2e-1, 10**-6, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
# axs[1].text(2e-1, 10**-9, r"$\epsilon_{522}$", fontsize=22, c="#393A10");
# axs[1].text(2e-1, 10**-12, r"$\epsilon_{533}$", fontsize=22, c="#F2A47D");
# axs[1].text(2e-1, 10**-15, r"$\epsilon_{544}$", fontsize=22, c="#8A7198");


plt.savefig("Solve_f14_eg2_alp_0831.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e18_ma_4.5e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=5.23597953858857e-10 * (1e18/1e12)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e8])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-13, r"$\alpha = 0.75$", fontsize=18);
axs[1].text(1e4, 1e-16, r"$f_a = 10^{18} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
axs[1].text(2e-2, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
axs[1].text(2e-2, 10**-12, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
axs[1].text(2e-2, 10**-15, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
axs[1].text(2e-1, 10**-6, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
axs[1].text(2e-1, 10**-9, r"$\epsilon_{511}$", fontsize=22, c="#393A10");
axs[1].text(2e-1, 10**-12, r"$\epsilon_{522}$", fontsize=22, c="#F2A47D");
axs[1].text(2e-1, 10**-15, r"$\epsilon_{533}$", fontsize=22, c="#8A7198");
axs[1].text(2, 10**-15, r"$\epsilon_{544}$", fontsize=22, c="#ED6E7D");

plt.savefig("Solve_f18_eg3_alp_075.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e16_ma_4.5e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=5.23597953858857e-10 * (1e4)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e2])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-14, r"$\alpha = 0.75$", fontsize=18);
axs[1].text(1e4, 1e-16, r"$f_a = 10^{16} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


# axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
# axs[1].text(2e-2, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
# axs[1].text(2e-2, 10**-12, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
# axs[1].text(2e-2, 10**-15, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
# axs[1].text(2e-1, 10**-6, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
# axs[1].text(2e-1, 10**-9, r"$\epsilon_{522}$", fontsize=22, c="#393A10");
# axs[1].text(2e-1, 10**-12, r"$\epsilon_{533}$", fontsize=22, c="#F2A47D");
# axs[1].text(2e-1, 10**-15, r"$\epsilon_{544}$", fontsize=22, c="#8A7198");


plt.savefig("Solve_f16_eg3_alp_075.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e14_ma_4.5e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=5.23597953858857e-10 * (1e2)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e-2])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-14, r"$\alpha = 0.75$", fontsize=18);
axs[1].text(1e4, 1e-16, r"$f_a = 10^{14} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


# axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
# axs[1].text(2e-2, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
# axs[1].text(2e-2, 10**-12, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
# axs[1].text(2e-2, 10**-15, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
# axs[1].text(2e-1, 10**-6, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
# axs[1].text(2e-1, 10**-9, r"$\epsilon_{522}$", fontsize=22, c="#393A10");
# axs[1].text(2e-1, 10**-12, r"$\epsilon_{533}$", fontsize=22, c="#F2A47D");
# axs[1].text(2e-1, 10**-15, r"$\epsilon_{544}$", fontsize=22, c="#8A7198");


plt.savefig("Solve_f14_eg3_alp_075.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e12_ma_4.5e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)

axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=5.23597953858857e-10
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e-7])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-15, r"$\alpha = 0.75$", fontsize=18);
axs[1].text(1e4, 1e-17, r"$f_a = 10^{12} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


# axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
# axs[1].text(1e1, 10**-14, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
# axs[1].text(1e1, 10**-15, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
# axs[1].text(1e1, 10**-16, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
# axs[1].text(1e1, 10**-17, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
# axs[1].text(7e1, 10**-14, r"$\epsilon_{522}$", fontsize=22, c="#393A10");
# axs[1].text(7e1, 10**-15, r"$\epsilon_{533}$", fontsize=22, c="#F2A47D");
# axs[1].text(7e1, 10**-16, r"$\epsilon_{544}$", fontsize=22, c="#8A7198");


plt.savefig("Solve_f12_eg3_alp_075.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e14_ma_4.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=8.181218029044644e-8
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
# axs[1].set_ylim([1e-18,1e-3])
axs[1].set_ylim([1e-18,1e-3])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e1, 10**-13.5, r"$n \leq 5$", fontsize=18);
axs[1].text(1e1, 10**-15, r"$\alpha = 0.66$", fontsize=18);
axs[1].text(1e1, 10**-16.5, r"$f_a = 10^{14} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


# axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
axs[1].text(2e-2, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
# axs[1].text(2e-2, 10**-12, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
# axs[1].text(2e-2, 10**-15, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
# axs[1].text(2e-1, 10**-6, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
# axs[1].text(2e-1, 10**-9, r"$\epsilon_{522}$", fontsize=22, c="#393A10");
# axs[1].text(2e-1, 10**-12, r"$\epsilon_{533}$", fontsize=22, c="#F2A47D");
axs[1].text(2e-2, 10**-11, r"$\epsilon_{544}$", fontsize=22, c="#ED6E7D");


plt.savefig("Solve_f14_n5_alp_066.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_FullRel_fa_1.0e14_ma_4.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)



axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

BN211=8.181218029044644e-8
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (5/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (5/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e-3])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
# axs[1].text(1e4, 1e-14, r"$\alpha \simeq 0.83$", fontsize=18);
# axs[1].text(1e4, 1e-16, r"$f_a = 10^{14} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);
axs[1].text(1e1, 10**-13.5, r"$n \leq 4$", fontsize=18);
axs[1].text(1e1, 10**-15, r"$\alpha = 0.66$", fontsize=18);
axs[1].text(1e1, 10**-16.5, r"$f_a = 10^{14} \, {\rm GeV}$", fontsize=18);


axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


# axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
axs[1].text(2e-2, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
# axs[1].text(2e-2, 10**-12, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
axs[1].text(2e-2, 10**-11, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
axs[1].text(2e-2, 10**-13, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
# axs[1].text(2e-1, 10**-9, r"$\epsilon_{522}$", fontsize=22, c="#393A10");
# axs[1].text(2e-1, 10**-12, r"$\epsilon_{533}$", fontsize=22, c="#F2A47D");
# axs[1].text(2e-1, 10**-15, r"$\epsilon_{544}$", fontsize=22, c="#8A7198");


plt.savefig("Solve_f14_n4_alp_066.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_NonRel_fa_1.0e18_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fa12N4 = np.loadtxt("../test_store/OutRun_Lvln4_NonRel_fa_1.0e18_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,2], "#031D44", lw=lww)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

lww=1.5
axs[1].plot(fa12N4[:,0], fa12N4[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
axs[1].plot(fa12N4[:,0], fa12N4[:,2], "#031D44", lw=lww, dashes=[4, 4])
axs[1].plot(fa12N4[:,0], fa12N4[:,3], "#00A676", lw=lww,  dashes=[4, 4])
axs[1].plot(fa12N4[:,0], fa12N4[:,4], "#B68F40", lw=lww, dashes=[4, 4])
axs[1].plot(fa12N4[:,0], fa12N4[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
axs[0].plot(fa12N4[:,0], fa12N4[:,-2], "k", lw=lww, dashes=[4, 4])

axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", ls = "dotted", lw=.6)



BN211=65.44974423235715
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (4/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e8])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-15, r"$f_a = 10^{18} \, {\rm GeV}$", fontsize=18);

axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
axs[1].text(2e-2, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
axs[1].text(2e-2, 10**-12, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
axs[1].text(2e-2, 10**-15, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
axs[1].text(2e-1, 10**-6, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");


plt.savefig("Solve_f18.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_NonRel_fa_1.0e16_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fa12N4 = np.loadtxt("../test_store/OutRun_Lvln4_NonRel_fa_1.0e16_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
c1 = fa12[:,0] < 2810.18295300705
c2 = fa12[:,1] < 1e-20
cc = np.any(np.vstack((c1,c2)),axis=0)
axs[1].plot(fa12[cc,0], fa12[cc,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[cc,0], fa12[cc,2], "#031D44", lw=lww)
axs[0].plot(fa12[cc,0], fa12[cc,-2], "k", lw=lww)

lww=1.5

c1 = fa12N4[:,0] < 1e5
c2 = fa12N4[:,1] < 1e-20
cc = np.any(np.vstack((c1,c2)),axis=0)

axs[1].plot(fa12N4[cc,0], fa12N4[cc,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
axs[1].plot(fa12N4[cc,0], fa12N4[cc,2], "#031D44", lw=lww, dashes=[4, 4])
axs[1].plot(fa12N4[cc,0], fa12N4[cc,3], "#00A676", lw=lww,  dashes=[4, 4])
axs[1].plot(fa12N4[cc,0], fa12N4[cc,4], "#B68F40", lw=lww, dashes=[4, 4])
axs[1].plot(fa12N4[cc,0], fa12N4[cc,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
axs[0].plot(fa12N4[cc,0], fa12N4[cc,-2], "k", lw=lww, dashes=[4, 4])

axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", ls = "dotted", lw=.6)



BN211=65.44974423235715 / (1e2)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (4/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e4])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-15, r"$f_a = 10^{16} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


# axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
# axs[1].text(2e-2, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
# axs[1].text(2e-2, 10**-12, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
# axs[1].text(2e-2, 10**-15, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
# axs[1].text(2e-1, 10**-6, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");


plt.savefig("Solve_f16.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_NonRel_fa_1.0e14_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fa12N4 = np.loadtxt("../test_store/OutRun_Lvln4_NonRel_fa_1.0e14_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,2], "#031D44", lw=lww)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

lww=1.5
axs[1].plot(fa12N4[:,0], fa12N4[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
axs[1].plot(fa12N4[:,0], fa12N4[:,2], "#031D44", lw=lww, dashes=[4, 4])
axs[1].plot(fa12N4[:,0], fa12N4[:,3], "#00A676", lw=lww,  dashes=[4, 4])
axs[1].plot(fa12N4[:,0], fa12N4[:,4], "#B68F40", lw=lww, dashes=[4, 4])
axs[1].plot(fa12N4[:,0], fa12N4[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
axs[0].plot(fa12N4[:,0], fa12N4[:,-2], "k", lw=lww, dashes=[4, 4])

axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", ls = "dotted", lw=.6)



BN211=65.44974423235715 / (1e4)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (4/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e-2])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-15, r"$f_a = 10^{14} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


# axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
# axs[1].text(2e-2, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
# axs[1].text(2e-2, 10**-12, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
# axs[1].text(2e-2, 10**-15, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
# axs[1].text(2e-1, 10**-6, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");


plt.savefig("Solve_f14.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_NonRel_fa_1.0e12_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fa12N4 = np.loadtxt("../test_store/OutRun_Lvln4_NonRel_fa_1.0e12_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,2], "#031D44", lw=lww)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)

lww=1.5
axs[1].plot(fa12N4[:,0], fa12N4[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
axs[1].plot(fa12N4[:,0], fa12N4[:,2], "#031D44", lw=lww, dashes=[4, 4])
axs[1].plot(fa12N4[:,0], fa12N4[:,3], "#00A676", lw=lww,  dashes=[4, 4])
axs[1].plot(fa12N4[:,0], fa12N4[:,4], "#B68F40", lw=lww, dashes=[4, 4])
axs[1].plot(fa12N4[:,0], fa12N4[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
axs[0].plot(fa12N4[:,0], fa12N4[:,-2], "k", lw=lww, dashes=[4, 4])

axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", ls = "dotted", lw=.6)



BN211=65.44974423235715 / (1e6)**2
axs[1].axhline(BN211, alpha=0.5, lw=1, ls ="dotted", c="k")
axs[1].axhline(BN211 * (3/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")
axs[1].axhline(BN211 * (4/2)**4, alpha=0.5, lw=lww, ls ="dotted", c="k")

axs[1].fill_between(fa12[:,0], np.ones(len(fa12[:,0])) * BN211 * (4/2)**4, 1e100, color="k",ec="k", alpha=0.1)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-18,1e-6])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[1].text(1e4, 1e-15, r"$f_a = 10^{12} \, {\rm GeV}$", fontsize=18);

# axs[1].text(1e-2, 1e4, r"Bosenova Threhsold", fontsize=15);

axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


# axs[1].text(2e-2, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
# axs[1].text(2e-2, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
# axs[1].text(2e-2, 10**-12, r"$\epsilon_{411}$", fontsize=22, c="#00A676");
# axs[1].text(2e-2, 10**-15, r"$\epsilon_{422}$", fontsize=22, c="#B68F40");
# axs[1].text(2e-1, 10**-6, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");


plt.savefig("Solve_f12.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e12_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")
n211 = np.loadtxt("../test_store/Trace_term_1_.dat")
n322 = np.loadtxt("../test_store/Trace_term_2_.dat")
n411 = np.loadtxt("../test_store/Trace_term_3_.dat")
n422 = np.loadtxt("../test_store/Trace_term_4_.dat")
n544 = np.loadtxt("../test_store/Trace_term_8_.dat")

# %%
fig, axs = plt.subplots(5, sharex=True,  figsize=(10,20), gridspec_kw={'hspace': 0.1})
lw=1
lww=1.3

unitS = 1.0 / 6.58e-16 * 3.15e7

num_per = 3
cList = ["#6F1D1B", "#031D44", "#00A676", "#B68F40", "#6DAEDB"]

## 211
sr_labl = ["322x322-211xInf", "411x422-211xInf", "211x411-322xBH", "322x433-211xInf", "211x322-433xBH",
           "422x322-211xInf", "322_211-GW", "433x433-211xInf", "211x211-322xBH", "211x422-433xBH", "322x411-211xInf", "211_322-GW",
           "211x211-211xInf", "211x211-422xBH", "211_211-GW"]


nrm = np.sum(np.abs(n211[:,1:]),axis=1)
tsort = np.argmin(np.abs(n422[:,0] - 0.25))
tsort2 = np.argmin(np.abs(n422[:,0] - 0.35))
check_high = []
for i in range(len(n211[1,:]) - 1): 
    # check_high.append(np.abs(n211[tsort,i + 1]) / nrm[tsort])
    check_high.append(np.mean(np.abs(n211[tsort:tsort2,i + 1])) )
check_high = np.asarray(check_high)
asrt = np.argsort(check_high)[::-1]


lsDash = [0, 0, 1, 0]
for i in range(num_per):
    # axs[0].plot(n211[:,0], np.abs(n211[:,asrt[i]+1]) / nrm, lw=lw, c=cList[i])
    if lsDash[i] == 0:
        axs[0].plot(n211[:,0], unitS* (np.abs(n211[:,asrt[i]+1])), lw=lw, c=cList[i])
    else:
        axs[0].plot(n211[:,0], unitS* (np.abs(n211[:,asrt[i]+1])), lw=lww, c=cList[i], dashes=[3, 3])
    
    axs[0].text(0.2, unitS * 10**(-17.5 - i * 0.45), sr_labl[asrt[i]], fontsize=12, c=cList[i])
# axs[0].plot([0.01,10.0], [unitS * 3.033823402214355e-19, unitS * 3.033823402214355e-19], lw=lw, c="k", dashes=[3,3])
axs[0].plot(n211[:,0], unitS *3.033823402214355e-19 * 10**e211I(np.log10(n211[:,0])) / ma, lw=lw, c="k", ls="dotted")

## 322
sr_labl = ["522x522-322_Inf", "322_322-GW", "322x322-211xInf", "533x533-322xInf", "211x411-322xBH", 
           "322x433-211_Inf", "411x411-322xBH", "211x322-433xBH", "522x544-322xInf", "322x411-433xBH",
           "422x322-211_Inf", "522x533-322xInf", "433x544-322xInf", "322x522-544xBH", "422x522-322xInf",
           "322x322-544_BH", "322x411-533xBH", "322_211-GW", "433x533-322xInf", "422x533-322xInf", 
           "211x211-322_BH", "322x411-211xInf", "422x544-322xInf", "533x544-322xInf",  "211_322-GW"
           "544x544-322_Inf", "322x422-544xBH"]


nrm = np.sum(np.abs(n322[:,1:]),axis=1)
tsort = np.argmin(np.abs(n422[:,0] - 0.25))
tsort2 = np.argmin(np.abs(n422[:,0] - 0.35))
check_high = []
for i in range(len(n322[1,:]) - 1): 
    check_high.append(np.mean(np.abs(n322[tsort:tsort2,i + 1])) )
check_high = np.asarray(check_high)
asrt = np.argsort(check_high)[::-1]

lsDash = [1, 0, 0, 0]
for i in range(num_per):
    if lsDash[i] == 0:
        axs[1].plot(n322[:,0],unitS * (np.abs(n322[:,asrt[i]+1])), lw=lw, c=cList[i])
    else:
        axs[1].plot(n322[:,0],unitS * (np.abs(n322[:,asrt[i]+1])), lw=lww, c=cList[i], dashes=[3, 3])
        
    axs[1].text(0.2, unitS * 10**(-17.5 - i * 0.45), sr_labl[asrt[i]], fontsize=12, c=cList[i])
# axs[1].plot([0.01,10.0], [unitS * 3.269054015933406e-23, unitS * 3.269054015933406e-23], lw=lw, c="k", ls="dotted")
    
## 411
sr_labl = ["411x422-211xInf", "411x411-522xBH", "211x411-322xBH", "411x411-322xBH", "322x411-433xBH", 
           "411x411-422xBH", "322x411-533xBH", "322x411-211xInf"]

nrm = np.sum(np.abs(n411[:,1:]),axis=1)
tsort = np.argmin(np.abs(n422[:,0] - 0.25))
tsort2 = np.argmin(np.abs(n422[:,0] - 0.35))
check_high = []
for i in range(len(n411[1,:]) - 1): 
    check_high.append(np.mean(np.abs(n411[tsort:tsort2,i + 1])) )
check_high = np.asarray(check_high)
asrt = np.argsort(check_high)[::-1]

lsDash = [0, 0, 0, 0]
for i in range(num_per):
    # axs[2].plot(n411[:,0], np.abs(n411[:,asrt[i]+1]) / nrm, lw=lw, c=cList[i])
    if lsDash[i] == 0:
        axs[2].plot(n411[:,0], unitS * (np.abs(n411[:,asrt[i]+1])), lw=lw, c=cList[i])
    else:
        axs[2].plot(n411[:,0], unitS * (np.abs(n411[:,asrt[i]+1])), lw=lw, c=cList[i], dashes=[3, 3])
        
    
    axs[2].text(0.2, unitS * 10**(-17.5 - i * 0.45), sr_labl[asrt[i]], fontsize=12, c=cList[i])
    
axs[2].plot(n411[:,0], unitS * 5.052935991920385e-20 * 10**e411I(np.log10(n411[:,0])) / ma, lw=lw, c="k", ls="dotted")
# axs[2].plot([0.01,10.0], [unitS * 5.052935991920385e-20, unitS * 5.052935991920385e-20], lw=lw, c="k", ls="dotted")
    
## 422
sr_labl = ["411_422_211_Inf", "422_422_544_BH", "422_322_211_Inf", "422_522_322_Inf", "411_411_422_BH",
           "422_533_322_Inf", "422_522_544_BH", "211_422_433_BH", "422_544_322_Inf", "211_211_422_BH",
           "322_422_544_BH"]

nrm = np.sum(np.abs(n422[:,1:]),axis=1)
tsort = np.argmin(np.abs(n422[:,0] - 0.25))
tsort2 = np.argmin(np.abs(n422[:,0] - 0.35))
check_high = []
for i in range(len(n422[1,:]) - 1): 
    check_high.append(np.mean(np.abs(n422[tsort:tsort2,i + 1])) )
check_high = np.asarray(check_high)
asrt = np.argsort(check_high)[::-1]

lsDash = [1, 0, 0, 0]
for i in range(num_per):
    if lsDash[i] == 0:
        axs[3].plot(n422[:,0],unitS * (np.abs(n422[:,asrt[i]+1])), lw=lw, c=cList[i])
    else:
        axs[3].plot(n422[:,0], unitS *(np.abs(n422[:,asrt[i]+1])), lw=lw, c=cList[i], dashes=[3, 3])
        
    
   # print(np.log10(np.abs(n422[:,asrt[i]+1])))
#    axs[3].text(0.2, .9 - i * 0.05, sr_labl[asrt[i]], fontsize=12, c=cList[i])
    axs[3].text(0.2, unitS *10**(-17.5 - i * 0.45), sr_labl[asrt[i]], fontsize=12, c=cList[i])

axs[3].plot([0.01,10.0],[unitS * 2.0420370540873277e-23, unitS * 2.0420370540873277e-23], lw=lw, c="k", ls="dotted")
    
    
## 544
sr_labl = ["422_422_544_BH", "522_544_322_Inf", "433_544_322_Inf", "322_522_544_BH", "322_322_544_BH",
           "522_522_544_BH", "422_522_544_BH", "422_544_322_Inf", "533_544_322_Inf", "544_544_322_Inf",
           "322_422_544_BH"]

nrm = np.sum(np.abs(n544[:,1:]),axis=1)
tsort = np.argmin(np.abs(n422[:,0] - 0.25))
tsort2 = np.argmin(np.abs(n422[:,0] - 0.35))
check_high = []
for i in range(len(n544[1,:]) - 1): 
    check_high.append(np.median(np.abs(n544[tsort:tsort2,i + 1])) )
check_high = np.asarray(check_high)
asrt = np.argsort(check_high)[::-1]
#print(check_high, asrt, n422[tsort,0], n422[tsort2,0])

lsDash = [0, 1, 0, 0]
for i in range(num_per):
    if lsDash[i] == 0:
        axs[4].plot(n544[:,0], unitS *(np.abs(n544[:,asrt[i]+1])), lw=lw, c=cList[i])
    else:
        axs[4].plot(n544[:,0], unitS * (np.abs(n544[:,asrt[i]+1])), lw=lw, c=cList[i], dashes=[3, 3])
        
    # axs[4].plot(n544[:,0], np.abs(n544[:,asrt[i]+1]) / nrm, lw=lw, c=cList[i])
    # axs[4].plot(n544[:,0], np.log10(np.abs(n544[:,asrt[i]+1])), lw=lw, c=cList[i])
    
    axs[4].text(0.2, unitS * 10**(-17.5 - i * .45), sr_labl[asrt[i]], fontsize=12, c=cList[i])
    
    

    
    
    
    
axs[3].set_xscale("linear")
axs[0].set_xlim([0.1,.26 ])
# axs[0].set_ylim([0.0,1 ])
# axs[1].set_ylim([0.0,1 ])
# axs[2].set_ylim([0.0,1])
# axs[3].set_ylim([0.0,1])
axs[0].set_yscale("log")
axs[1].set_yscale("log")
axs[2].set_yscale("log")
axs[3].set_yscale("log")
axs[0].set_ylim([unitS * 1e-22,unitS * 1e-17])
axs[1].set_ylim([unitS * 1e-22,unitS *1e-17])
axs[2].set_ylim([unitS * 1e-22,unitS *1e-17])
axs[3].set_ylim([unitS * 1e-22,unitS *1e-17])
# axs[4].set_ylim([0.0,1.2])
axs[4].set_yscale("log")
axs[4].set_ylim([unitS *1e-22,unitS *1e-17])

axs[4].set_xlabel(r"t   [yrs]", fontsize=23);
axs[0].set_ylabel(r"$\mathcal{R}_x$  [1/yr]", fontsize=23);
axs[1].set_ylabel(r"$\mathcal{R}_x$  [1/yr]", fontsize=23);
axs[2].set_ylabel(r"$\mathcal{R}_x$  [1/yr]", fontsize=23);
axs[3].set_ylabel(r"$\mathcal{R}_x$  [1/yr]", fontsize=23);
axs[4].set_ylabel(r"$\mathcal{R}_x$  [1/yr]", fontsize=23);

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e12_ma_2.0e-12_MBH_22.2_spin_0.99_v2_.dat")
n211 = np.loadtxt("../test_store/Trace_term_1_.dat")
n322 = np.loadtxt("../test_store/Trace_term_2_.dat")
n411 = np.loadtxt("../test_store/Trace_term_3_.dat")
n422 = np.loadtxt("../test_store/Trace_term_4_.dat")
n544 = np.loadtxt("../test_store/Trace_term_8_.dat")

# %%
from scipy.interpolate import interp1d

# %%
e211I = interp1d(np.log10(fa12[:,0]), np.log10(fa12[:,1]))
e322I = interp1d(np.log10(fa12[:,0]), np.log10(fa12[:,2]))
e411I = interp1d(np.log10(fa12[:,0]), np.log10(fa12[:,3]))
e422I = interp1d(np.log10(fa12[:,0]), np.log10(fa12[:,4]))
# Out:
# /var/folders/2g/0h7xb5296_l51vyp88_ldzm80000gn/T/ipykernel_77765/2036283550.py:1: RuntimeWarning: divide by zero encountered in log10
#   e211I = interp1d(np.log10(fa12[:,0]), np.log10(fa12[:,1]))
# /var/folders/2g/0h7xb5296_l51vyp88_ldzm80000gn/T/ipykernel_77765/2036283550.py:2: RuntimeWarning: divide by zero encountered in log10
#   e322I = interp1d(np.log10(fa12[:,0]), np.log10(fa12[:,2]))
# /var/folders/2g/0h7xb5296_l51vyp88_ldzm80000gn/T/ipykernel_77765/2036283550.py:3: RuntimeWarning: divide by zero encountered in log10
#   e411I = interp1d(np.log10(fa12[:,0]), np.log10(fa12[:,3]))
# /var/folders/2g/0h7xb5296_l51vyp88_ldzm80000gn/T/ipykernel_77765/2036283550.py:4: RuntimeWarning: divide by zero encountered in log10
#   e422I = interp1d(np.log10(fa12[:,0]), np.log10(fa12[:,4]))

# %%
fig, axs = plt.subplots(5, sharex=True,  figsize=(10,20), gridspec_kw={'hspace': 0.1})
lw=1
lww=1.3

ma=2e-12
unitS = ma / 6.58e-16 * 3.15e7

num_per = 3
cList = ["#6F1D1B", "#031D44", "#00A676", "#B68F40", "#6DAEDB"]

## 211
sr_labl = ["322x322-211xInf", "411x422-211xInf", "211x411-322xBH", "322x433-211xInf", "211x322-433xBH",
           "422x322-211xInf", "322_211-GW", "433x433-211xInf", "211x211-322xBH", "211x422-433xBH", "322x411-211xInf", "211_322-GW",
           "211x211-211xInf", "211x211-422xBH", "211_211-GW"]


lsDash = [0, 0, 1]
tempP = np.zeros_like(n211[:,1])
tempP += unitS * 3.033823402214355e-19 * 10**e211I(np.log10(n211[:,0])) / ma
tempN = np.zeros_like(n211[:,1])
for i in range(len(sr_labl)):
    if (sr_labl[i][0:3] == "211")or(sr_labl[i][4:7] == "211"):
        tempN +=  unitS* (np.abs(n211[:,i+1]))
    else:
        tempP +=  unitS* (np.abs(n211[:,i+1]))
axs[0].plot(n211[:,0], tempP, lw=lww, c=cList[0], dashes=[3, 3])    
axs[0].plot(n211[:,0], tempN, lw=lww, c=cList[1])    

## 322
sr_labl = ["522x522-322_Inf", "322_322-GW", "322x322-211xInf", "533x533-322xInf", "211x411-322xBH", 
           "322x433-211_Inf", "411x411-322xBH", "211x322-433xBH", "522x544-322xInf", "322x411-433xBH",
           "422x322-211_Inf", "522x533-322xInf", "433x544-322xInf", "322x522-544xBH", "422x522-322xInf",
           "322x322-544_BH", "322x411-533xBH", "322_211-GW", "433x533-322xInf", "422x533-322xInf", 
           "211x211-322_BH", "322x411-211xInf", "422x544-322xInf", "533x544-322xInf",  "211_322-GW"
           "544x544-322_Inf", "322x422-544xBH"]


tempP = np.zeros_like(n322[:,1])
tempP += unitS * 3.269054015933406e-23 * 10**e322I(np.log10(n211[:,0])) / ma
tempN = np.zeros_like(n322[:,1])
for i in range(len(sr_labl)):
    if (sr_labl[i][0:3] == "322")or(sr_labl[i][4:7] == "322"):
        tempN +=  unitS* (np.abs(n322[:,i+1]))
    else:
        tempP +=  unitS* (np.abs(n322[:,i+1]))
axs[1].plot(n322[:,0], tempP, lw=lww, c=cList[0], dashes=[3, 3])    
axs[1].plot(n322[:,0], tempN, lw=lww, c=cList[1])  


## 411
sr_labl = ["411x422-211xInf", "411x411-522xBH", "211x411-322xBH", "411x411-322xBH", "322x411-433xBH", 
           "411x411-422xBH", "322x411-533xBH", "322x411-211xInf"]
tempP = np.zeros_like(n411[:,1])
tempP += unitS *5.052935991920385e-20 * 10**e411I(np.log10(n211[:,0])) / ma
tempN = np.zeros_like(n411[:,1])
for i in range(len(sr_labl)):
    if (sr_labl[i][0:3] == "411")or(sr_labl[i][4:7] == "411"):
        tempN +=  unitS* (np.abs(n411[:,i+1]))
    else:
        tempP +=  unitS* (np.abs(n411[:,i+1]))
axs[2].plot(n411[:,0], tempP, lw=lww, c=cList[0], dashes=[3, 3])    
axs[2].plot(n411[:,0], tempN, lw=lww, c=cList[1])  
  
## 422
sr_labl = ["411_422_211_Inf", "422_422_544_BH", "422_322_211_Inf", "422_522_322_Inf", "411_411_422_BH",
           "422_533_322_Inf", "422_522_544_BH", "211_422_433_BH", "422_544_322_Inf", "211_211_422_BH",
           "322_422_544_BH"]

tempP = np.zeros_like(n422[:,1])
tempP += unitS *2.0420370540873277e-23  * 10**e422I(np.log10(n211[:,0])) / ma
tempN = np.zeros_like(n422[:,1])
for i in range(len(sr_labl)):
    if (sr_labl[i][0:3] == "422")or(sr_labl[i][4:7] == "422"):
        tempN +=  unitS* (np.abs(n422[:,i+1]))
    else:
        tempP +=  unitS* (np.abs(n422[:,i+1]))
axs[3].plot(n422[:,0], tempP, lw=lww, c=cList[0], dashes=[3, 3])    
axs[3].plot(n422[:,0], tempN, lw=lww, c=cList[1])  
  
    
## 544
sr_labl = ["422_422_544_BH", "522_544_322_Inf", "433_544_322_Inf", "322_522_544_BH", "322_322_544_BH",
           "522_522_544_BH", "422_522_544_BH", "422_544_322_Inf", "533_544_322_Inf", "544_544_322_Inf",
           "322_422_544_BH"]

tempP = np.zeros_like(n544[:,1])
tempN = np.zeros_like(n544[:,1])
for i in range(len(sr_labl)):
    if (sr_labl[i][0:3] == "544")or(sr_labl[i][4:7] == "544"):
        tempN +=  unitS* (np.abs(n544[:,i+1]))
    else:
        tempP +=  unitS* (np.abs(n544[:,i+1]))
axs[4].plot(n544[:,0], tempP, lw=lww, c=cList[0], dashes=[3, 3])    
axs[4].plot(n544[:,0], tempN, lw=lww, c=cList[1])  

    
axs[0].text(0.24, 1e-7, r"$\left| 211 \right>$", fontsize=20)
axs[1].text(0.24, 1e-7, r"$\left| 322 \right>$", fontsize=20)
axs[2].text(0.24, 1e-7, r"$\left| 411 \right>$", fontsize=20)
axs[3].text(0.24, 1e-7, r"$\left| 422 \right>$", fontsize=20)
axs[4].text(0.24, 1e-7, r"$\left| 544 \right>$", fontsize=20)
    
    
    
axs[3].set_xscale("linear")
axs[0].set_xlim([0.1,.26 ])
# axs[0].set_ylim([0.0,1 ])
# axs[1].set_ylim([0.0,1 ])
# axs[2].set_ylim([0.0,1])
# axs[3].set_ylim([0.0,1])
axs[0].set_yscale("log")
axs[1].set_yscale("log")
axs[2].set_yscale("log")
axs[3].set_yscale("log")
axs[0].set_ylim([unitS * 1e-22,unitS * 1e-17])
axs[1].set_ylim([unitS * 1e-22,unitS *1e-17])
axs[2].set_ylim([unitS * 1e-22,unitS *1e-17])
axs[3].set_ylim([unitS * 1e-22,unitS *1e-17])
# axs[4].set_ylim([0.0,1.2])
axs[4].set_yscale("log")
axs[4].set_ylim([unitS *1e-22,unitS *1e-17])

axs[4].set_xlabel(r"t   [yrs]", fontsize=23);
axs[0].set_ylabel(r"$\mathcal{R}_\pm$  [1/yr]", fontsize=23);
axs[1].set_ylabel(r"$\mathcal{R}_\pm$  [1/yr]", fontsize=23);
axs[2].set_ylabel(r"$\mathcal{R}_\pm$  [1/yr]", fontsize=23);
axs[3].set_ylabel(r"$\mathcal{R}_\pm$  [1/yr]", fontsize=23);
axs[4].set_ylabel(r"$\mathcal{R}_\pm$  [1/yr]", fontsize=23);

plt.savefig("rates_crazy_pm.jpeg", dpi=200, bbox_inches='tight')

# %%
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,10), gridspec_kw={'hspace': 0.1})
lw=1
lww=1.3

ma=2e-12
unitS = ma / 6.58e-16 * 3.15e7

num_per = 3
cList = ["#6F1D1B", "#031D44", "#00A676", "#B68F40", "#6DAEDB"]


    
## 411

sr_labl = ["411x422-211xInf", "411x411-522xBH", "211x411-322xBH", "411x411-322xBH", "322x411-433xBH", 
           "411x411-422xBH", "322x411-533xBH", "322x411-211xInf"]

sr_labl = [r"$411 \times 422 \rightarrow 211 \times \infty$", "411x411-522xBH", "211x411-322xBH", "411x411-322xBH", "322x411-433xBH", 
           r"$411 \times 411 \rightarrow 422 \times {\rm BH}$", "322x411-533xBH", r"$322 \times 411 \rightarrow 211 \times \infty$"]

nrm = np.sum(np.abs(n411[:,1:]),axis=1)
tsort = np.argmin(np.abs(n422[:,0] - 0.25))
tsort2 = np.argmin(np.abs(n422[:,0] - 0.35))
check_high = []
for i in range(len(n411[1,:]) - 1): 
    check_high.append(np.mean(np.abs(n411[tsort:tsort2,i + 1])) / nrm[tsort])
check_high = np.asarray(check_high)
asrt = np.argsort(check_high)[::-1]

lsDash = [0, 0, 0]
for i in range(num_per):
    # axs[2].plot(n411[:,0], np.abs(n411[:,asrt[i]+1]) / nrm, lw=lw, c=cList[i])
    if lsDash[i] == 0:
        axs[0].plot(n411[:,0], unitS * (np.abs(n411[:,asrt[i]+1])), lw=lw, c=cList[i])
    else:
        axs[0].plot(n411[:,0], unitS * (np.abs(n411[:,asrt[i]+1])), lw=lw, c=cList[i], dashes=[3, 3])
        
    
    axs[0].text(0.2, unitS * 10**(-17.5 - i * 0.45), sr_labl[asrt[i]], fontsize=12, c=cList[i])

axs[0].plot(n411[:,0], unitS * 5.052935991920385e-20 * 10**e411I(np.log10(n411[:,0])) / ma, lw=lw, c="k", ls="dotted")
   
    
## 544

## 544



sr_labl = [ r"$422 \times 422 \rightarrow 544 \times {\rm BH}$",  r"$544 \times 522 \rightarrow 322 \times \infty$" , "433_544_322_Inf", "322_522_544_BH", 
           r"$322 \times 322 \rightarrow 544 \times {\rm BH}$",
           "522_522_544_BH", "422_522_544_BH", "422_544_322_Inf", "533_544_322_Inf", r"$544 \times 544 \rightarrow 322 \times \infty$" , 
           "322_422_544_BH"]

nrm = np.sum(np.abs(n544[:,1:]),axis=1)
tsort = np.argmin(np.abs(n422[:,0] - 0.25))
tsort2 = np.argmin(np.abs(n422[:,0] - 0.35))
check_high = []
for i in range(len(n544[1,:]) - 1): 
    check_high.append(np.median(np.abs(n544[tsort:tsort2,i + 1])) / nrm[tsort])
check_high = np.asarray(check_high)
asrt = np.argsort(check_high)[::-1]
#print(check_high, asrt, n422[tsort,0], n422[tsort2,0])

lsDash = [0, 1, 0]
for i in range(num_per):
    if lsDash[i] == 0:
        axs[1].plot(n544[:,0], unitS *(np.abs(n544[:,asrt[i]+1])), lw=lw, c=cList[i])
    else:
        axs[1].plot(n544[:,0], unitS * (np.abs(n544[:,asrt[i]+1])), lw=lw, c=cList[i], dashes=[3, 3])
        
    # axs[4].plot(n544[:,0], np.abs(n544[:,asrt[i]+1]) / nrm, lw=lw, c=cList[i])
    # axs[4].plot(n544[:,0], np.log10(np.abs(n544[:,asrt[i]+1])), lw=lw, c=cList[i])
    
    axs[1].text(0.2, unitS * 10**(-17.5 - i * .45), sr_labl[asrt[i]], fontsize=12, c=cList[i])
    
    

axs[0].text(0.24, 1e-7, r"$\left| 411 \right>$", fontsize=20)
axs[1].text(0.24, 1e-7, r"$\left| 544 \right>$", fontsize=20)
    
    
    
    
axs[1].set_xscale("linear")
axs[0].set_xlim([0.1,.26 ])
# axs[0].set_ylim([0.0,1 ])
# axs[1].set_ylim([0.0,1 ])
# axs[2].set_ylim([0.0,1])
# axs[3].set_ylim([0.0,1])
axs[0].set_yscale("log")
axs[1].set_yscale("log")

axs[0].set_ylim([unitS * 1e-22,unitS * 1e-17])
axs[1].set_ylim([unitS * 1e-22,unitS *1e-17])


axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
axs[0].set_ylabel(r"$\mathcal{R}_x$  [1/yr]", fontsize=23);
axs[1].set_ylabel(r"$\mathcal{R}_x$  [1/yr]", fontsize=23);

plt.savefig("rates_crazy_indiv.jpeg", dpi=200, bbox_inches='tight')

# %%
aa[0:3]
# Out:
# '322'

# %%
aa[4:7]
# Out:
# '322'

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e20_ma_3.5e-12_MBH_10.0_spin_0.98_fortalk_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-13,1e0])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
# axs[1].text(1e4, 1e-15, r"Non-Interacting", fontsize=18);



axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


axs[1].text(2e-1, 10**-6.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
axs[1].text(2e-1, 10**-9, r"$\epsilon_{322}$", fontsize=22, c="#031D44");


plt.savefig("Ex_talk_1.jpeg", dpi=200, bbox_inches='tight')

# %%
fa12 = np.loadtxt("../test_store/OutRun_Lvln4_Lvln5_FullRel_fa_1.0e13_ma_3.5e-12_MBH_10.0_spin_0.98_fortalk_.dat")
fig, axs = plt.subplots(2, sharex=True,  figsize=(10,6), gridspec_kw={'hspace': 0.07, 'height_ratios': [1, 3]})

lww=0.8

# axs[1].plot(f12_NR[:,0], f12_NR[:,1], "#6F1D1B", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,2], "#031D44", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,3], "#00A676", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,4], "#B68F40", lw=lww, dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,5], "#6DAEDB", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,6], "y", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,7], "g", lw=lww,  dashes=[4, 4])
# axs[1].plot(f12_NR[:,0], f12_NR[:,8], "k", lw=lww,  dashes=[4, 4])

lww=1.1
axs[1].plot(fa12[:,0], fa12[:,1], "#6F1D1B", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,3], "#031D44", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,4], "#00A676", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,5], "#B68F40", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,6], "#6DAEDB", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,7], "#393A10", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,8], "#F2A47D", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,9], "#8A7198", lw=lww)
axs[1].plot(fa12[:,0], fa12[:,10], "#ED6E7D", lw=lww)


axs[0].plot([1e-5, 1e7], [0.99, 0.99], "k", dashes=[4, 4], lw=.6)
axs[0].plot(fa12[:,0], fa12[:,-2], "k", lw=lww)


axs[1].set_yscale("log")
axs[0].set_yscale("linear")
axs[1].set_xscale("log")
axs[1].set_ylim([1e-13,1e0])
# axs[1].set_xlim([10,5e6])
axs[1].set_xlim([5e-3,4.8e6])
axs[0].set_ylim([-0.05,1.2])
axs[0].set_ylabel(r"$\tilde{a}$", fontsize=23)
axs[1].set_ylabel(r"$\epsilon_x$", fontsize=23)
axs[1].set_xlabel(r"t   [yrs]", fontsize=23);
# axs[1].text(1e4, 1e-15, r"Non-Interacting", fontsize=18);



axs[1].xaxis.set_minor_locator(mpl.ticker.LogLocator(subs="all", numticks=90))
axs[1].xaxis.set_major_locator(mpl.ticker.LogLocator(numticks=90))


axs[1].text(5e-2, 10**-5.0, r"$\epsilon_{211}$", fontsize=22, c="#6F1D1B");
axs[1].text(5e-2, 10**-7, r"$\epsilon_{322}$", fontsize=22, c="#031D44");
axs[1].text(5e-2, 10**-9, r"$\epsilon_{411}$", fontsize=22, c="#00A676");



axs[1].text(5e-1, 10**-5, r"$\epsilon_{433}$", fontsize=22, c="#6DAEDB");
axs[1].text(5e-1, 10**-7, r"$\epsilon_{511}$", fontsize=22, c="#393A10");
axs[1].text(5e-1, 10**-9, r"$\epsilon_{533}$", fontsize=22, c="#8A7198");



plt.savefig("Ex_talk_2.jpeg", dpi=200, bbox_inches='tight')
