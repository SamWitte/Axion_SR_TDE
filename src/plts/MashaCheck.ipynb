# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
fileMe1 = np.loadtxt("../test_store/OutRun_fa_1.0e11_ma_8.0e-13_MBH_10.0_spin_0.9.dat")
fileMe2 = np.loadtxt("../test_store/OutRun_fa_5.0e12_ma_8.0e-13_MBH_10.0_spin_0.9.dat")
fileMe3 = np.loadtxt("../test_store/OutRun_fa_5.0e14_ma_8.0e-13_MBH_10.0_spin_0.9.dat")


fileMa1 = np.loadtxt("../test_store/masha_fig9/1e-11_time.dat")
fileMa2 = np.loadtxt("../test_store/masha_fig9/5e-12_time.dat")
fileMa3 = np.loadtxt("../test_store/masha_fig9/5e-14_time.dat")

# %%
plt.plot(fileMe1[:,0], fileMe1[:,3], "r")
plt.plot(fileMe2[:,0], fileMe2[:,3], "b")
plt.plot(fileMe3[:,0], fileMe3[:,3], "k")

plt.plot(fileMa1[:,0], fileMa1[:,1], "r", ls="--")
plt.plot(fileMa2[:,0], fileMa2[:,1], "b", ls="--")
plt.plot(fileMa3[:,0], fileMa3[:,1], "k", ls="--")


plt.scatter(np.array([1e4]), np.array([0.75]))

plt.xscale("log")
plt.ylim([0.2, .95])
plt.xlim([1e3, 1e10])
# Out:
# (1000.0, 10000000000.0)
