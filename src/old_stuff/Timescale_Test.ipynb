# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

###########################
# Setup Plotting Defaults #
###########################
# For more options see https://matplotlib.org/users/customizing.html

# Commands for high detail plots (much larger in file size though)
#mpl.rcParams['agg.path.chunksize'] = 1000
#mpl.rcParams['savefig.dpi'] = 1000

# Line styles
mpl.rcParams['lines.linewidth'] = 1.5
mpl.rcParams['lines.antialiased'] = True
mpl.rcParams['lines.dashed_pattern'] = 2.8, 1.5
mpl.rcParams['lines.dashdot_pattern'] = 4.8, 1.5, 0.8, 1.5
mpl.rcParams['lines.dotted_pattern'] = 1.1, 1.1
mpl.rcParams['lines.scale_dashes'] = True

# Default colors
from cycler import cycler
mpl.rcParams['axes.prop_cycle'] = cycler('color',['cornflowerblue','forestgreen','maroon','goldenrod','firebrick','mediumorchid', 'navy', 'brown'])


# Fonts
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.serif'] = 'Helvetica'
mpl.rcParams['font.sans-serif'] = 'CMU Sans Serif, DejaVu Sans, Bitstream Vera Sans, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif'
mpl.rcParams['text.usetex'] = True

# Axes
mpl.rcParams['axes.linewidth'] = 1.0
mpl.rcParams['axes.labelsize'] = 24
mpl.rcParams['axes.labelpad'] = 10.0
                                                  
                                                  
# Tick marks - the essence of life
mpl.rcParams['xtick.top'] = True
mpl.rcParams['xtick.major.size'] = 10
mpl.rcParams['xtick.minor.size'] = 5
mpl.rcParams['xtick.major.width'] = 1.0
mpl.rcParams['xtick.minor.width'] = 0.75
mpl.rcParams['xtick.major.pad'] = 8
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['xtick.direction'] = 'in'
mpl.rcParams['xtick.minor.visible'] = True
mpl.rcParams['ytick.right'] = True
mpl.rcParams['ytick.major.size'] = 10
mpl.rcParams['ytick.minor.size'] = 5
mpl.rcParams['ytick.major.width'] = 1.0
mpl.rcParams['ytick.minor.width'] = 0.75
mpl.rcParams['ytick.major.pad'] = 8
mpl.rcParams['ytick.labelsize'] = 14
mpl.rcParams['ytick.direction'] = 'in'
mpl.rcParams['ytick.minor.visible'] = True

# Legend
mpl.rcParams['legend.fontsize'] = 14
mpl.rcParams['legend.frameon'] = True
mpl.rcParams['legend.framealpha'] = 0.8
#mpl.rcParams['legend.edgecolor'] = 'black'
mpl.rcParams['legend.fancybox'] = True
mpl.rcParams['legend.borderpad'] = 0.4 # border whitespace
mpl.rcParams['legend.labelspacing'] = 0.5 # the vertical space between the legend entries
mpl.rcParams['legend.handlelength'] = 1.5 # the length of the legend lines
mpl.rcParams['legend.handleheight'] = 0.7 # the height of the legend handle
mpl.rcParams['legend.handletextpad'] = 0.5 # the space between the legend line and legend text
mpl.rcParams['legend.borderaxespad'] = 0.5 # the border between the axes and legend edge
mpl.rcParams['legend.columnspacing'] = 2.0 # column separation


# Figure size
#mpl.rcParams['figure.figsize'] = 10, 6

# Save details
mpl.rcParams['savefig.bbox'] = 'tight'
mpl.rcParams['savefig.pad_inches'] = 0.1

# %%
hbar = 6.58e-16
s_to_Myr = 1.0 / 3.15e7 / 1e6
GNew = 7484169213.9427
Mp = 1.22e19

# %%
M = 22.2
# mu = 1e-12
# alph = mu * M * GNew
alphV = np.logspace(np.log10(0.03), 0, 50)
mu = alphV / (GNew * M)

loadSR = np.loadtxt("test_store/211_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR211 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

loadSR = np.loadtxt("test_store/311_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR311 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

loadSR = np.loadtxt("test_store/411_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR411 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years


loadSR = np.loadtxt("test_store/431_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR431 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years


loadSR = np.loadtxt("test_store/421_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR421 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

plt.plot(alphV, tauSR421, "y")
plt.plot(alphV, tauSR431, "g")

plt.plot(alphV, tauSR411, "r")
plt.plot(alphV, tauSR311, "orange")
plt.plot(alphV, tauSR211,"blue")

# plt.vlines(0.3322971130990562, 0, 1e12)


plt.plot(alphV, np.ones_like(alphV) * 4e6, "k", ls="--")
plt.plot(alphV, np.ones_like(alphV) * 4e6 / 200, "k", ls="--")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-4, 1e12])
plt.xlim([0.034, 1])
plt.xlabel(r"$\alpha$",fontsize=25)
plt.ylabel(r"$\tau$",fontsize=25)
# Out:
# Text(0, 0.5, '$\\tau$')

# %%
M = 22.2
# mu = 1e-12
# alph = mu * M * GNew
alphV = np.logspace(np.log10(0.03), 0, 50)
mu = alphV / (GNew * M)

loadSR = np.loadtxt("test_store/311_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR311 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years



plt.plot(alphV, np.ones_like(alphV) * 4e6, "k", ls="--")
plt.plot(alphV, np.ones_like(alphV) * 4e6 / 200, "k", ls="--")

plt.plot(alphV, tauSR311, "orange")


fa = 1e14
epsilon_211MAX = 1024 * np.pi * (fa / Mp)**2 / (9 * alphV**3)
# 211 x 311 -> 322 x BH
tau322Inf = (3e-10 * alphV**3 * mu * (Mp / fa)**4  * (epsilon_211MAX * 1e-4) * (epsilon_211MAX *1e-1) / hbar * 3.15e7)**(-1)
plt.plot(alphV, tau322Inf, ls="--")




plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-12, 1e12])
plt.xlim([0.034, 1])
plt.xlabel(r"$\alpha$",fontsize=25)
plt.ylabel(r"$\tau$",fontsize=25)
# Out:
# Text(0, 0.5, '$\\tau$')

# %%
M = 22.2
# mu = 1e-12
# alph = mu * M * GNew
alphV = np.logspace(np.log10(0.03), 0, 50)
mu = alphV / (GNew * M)

loadSR = np.loadtxt("test_store/321_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR311 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

## CANT BE POPULATED!

plt.plot(alphV, np.ones_like(alphV) * 4e6, "k", ls="--")
plt.plot(alphV, np.ones_like(alphV) * 4e6 / 200, "k", ls="--")

plt.plot(alphV, tauSR311, "orange")






plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-12, 1e12])
plt.xlim([0.034, 1])
plt.xlabel(r"$\alpha$",fontsize=25)
plt.ylabel(r"$\tau$",fontsize=25)
# Out:
# Text(0, 0.5, '$\\tau$')

# %%
M = 22.2
# mu = 1e-12
# alph = mu * M * GNew
alphV = np.logspace(np.log10(0.03), 0, 50)
mu = alphV / (GNew * M)


loadSR = np.loadtxt("test_store/322_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR322 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years


loadSR = np.loadtxt("test_store/422_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR422 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years


loadSR = np.loadtxt("test_store/432_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR432 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years


plt.plot(alphV, tauSR422)
plt.plot(alphV, tauSR322)
plt.plot(alphV, tauSR432, "y")


plt.plot(alphV, np.ones_like(alphV) * 4e6, "k", ls="--")
plt.plot(alphV, np.ones_like(alphV) * 4e6 / 200, "k", ls="--")



## testing 432
### injection
fa = 1e18
epsilon_211MAX = 1024 * np.pi * (fa / Mp)**2 / (9 * alphV**3)
# 211 x 211 -> 432 x BH
tau322Inf = (4e-14 * alphV**11 * mu * (Mp / fa)**4  * epsilon_211MAX * epsilon_211MAX / hbar * 3.15e7)**(-1)
plt.plot(alphV, tau322Inf, ls="--", c="g")

epsilon_411MAX = 1024 * np.pi * (fa / Mp)**2 / (9 * alphV**3)  * (4 / 2)**4
# 411 x 411 -> 432 x BH
tau322Inf = (2e-11 * alphV**11 * mu * (Mp / fa)**4  * epsilon_211MAX * epsilon_211MAX / hbar * 3.15e7)**(-1)
plt.plot(alphV, tau322Inf, ls="--", c="g")

### dissipation # 432 + 211 -> 433 + BH
tau322Inf = (1e-8 * alphV**7 * mu * (Mp / fa)**4  * epsilon_211MAX * (epsilon_211MAX * 1e-1) / hbar * 3.15e7)**(-1)
plt.plot(alphV, tau322Inf, ls="--", c="r")


plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-12, 1e8])
plt.xlim([0.034, 1])
plt.xlabel(r"$\alpha$",fontsize=25)
plt.ylabel(r"$\tau$",fontsize=25)
# Out:
# Text(0, 0.5, '$\\tau$')

# %%
M = 22.2
# mu = 1e-12
# alph = mu * M * GNew
alphV = np.logspace(np.log10(0.03), 0, 50)
mu = alphV / (GNew * M)


loadSR = np.loadtxt("test_store/433_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR433 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years


plt.plot(alphV, tauSR433)



plt.plot(alphV, np.ones_like(alphV) * 4e6, "k", ls="--")
plt.plot(alphV, np.ones_like(alphV) * 4e6 / 200, "k", ls="--")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-4, 1e8])
plt.xlim([0.034, 1])
plt.xlabel(r"$\alpha$",fontsize=25)
plt.ylabel(r"$\tau$",fontsize=25)
# Out:
# Text(0, 0.5, '$\\tau$')

# %%
M = 22.2
fa = 1e18
a = 0.9
alphV = np.logspace(np.log10(0.03), 0, 50)
mu = alphV / (GNew * M)

epsilon_211MAX = 1024 * np.pi * (fa / Mp)**2 / (9 * alphV**3)
# epsilon_3MAX = epsilon_211MAX *  (3 / 2)**4
epsilon_211MAX[epsilon_211MAX > 0.07] = 0.07 

    
loadSR = np.loadtxt("test_store/322_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR322 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

plt.plot(alphV, tauSR322)


# 211 x 211 -> 322 x BH
tau211BH = (4e-7 * alphV**11 * mu * (Mp / fa)**4 * (1 + np.sqrt(1 - a**2)) * epsilon_211MAX * epsilon_211MAX / hbar * 3.15e7)**(-1)
# 322 x 322 -> 211 x inf
tau322Inf = (1e-8 * alphV**8 * mu * (Mp / fa)**4  * epsilon_211MAX * epsilon_211MAX / hbar * 3.15e7)**(-1)
plt.plot(alphV, tau211BH)
plt.plot(alphV, tau322Inf)

fa = 1e16
# 211 x 211 -> 322 x BH
tau211BH = (4e-7 * alphV**11 * mu * (Mp / fa)**4 * (1 + np.sqrt(1 - a**2)) * epsilon_211MAX * epsilon_211MAX / hbar * 3.15e7)**(-1)
# 322 x 322 -> 211 x inf
tau322Inf = (1e-8 * alphV**8 * mu * (Mp / fa)**4  * epsilon_211MAX * epsilon_211MAX / hbar * 3.15e7)**(-1)
plt.plot(alphV, tau211BH, ls="--")
plt.plot(alphV, tau322Inf, ls="--")


plt.plot(alphV, np.ones_like(alphV) * 4e6, "k", ls="--")
plt.plot(alphV, np.ones_like(alphV) * 4e6 / 200, "k", ls="--")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-6, 1e8])
plt.xlim([0.034, 1])
plt.xlabel(r"$\alpha$",fontsize=25)
plt.ylabel(r"$\tau$",fontsize=25)
# Out:
# Text(0, 0.5, '$\\tau$')

# %%
M = 22.2
# mu = 1e-12
# alph = mu * M * GNew
alphV = np.logspace(np.log10(0.03), 0, 50)
mu = alphV / (GNew * M)


loadSR = np.loadtxt("test_store/511_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR511 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

loadSR = np.loadtxt("test_store/522_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR522 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

loadSR = np.loadtxt("test_store/521_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR521 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

plt.plot(alphV, tauSR511)
plt.plot(alphV, tauSR522)
plt.plot(alphV, tauSR521)



plt.plot(alphV, np.ones_like(alphV) * 4e6, "k", ls="--")
plt.plot(alphV, np.ones_like(alphV) * 4e6 / 180, "k", ls="--")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-4, 1e8])
plt.xlim([0.034, 1])
plt.xlabel(r"$\alpha$",fontsize=25)
plt.ylabel(r"$\tau$",fontsize=25)
# Out:
# Text(0, 0.5, '$\\tau$')

# %%
M = 22.2
# mu = 1e-12
# alph = mu * M * GNew
alphV = np.logspace(np.log10(0.03), 0, 50)
mu = alphV / (GNew * M)


loadSR = np.loadtxt("test_store/531_new_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR531 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

loadSR = np.loadtxt("test_store/532_new_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR532 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

loadSR = np.loadtxt("test_store/533_new_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR533 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

plt.plot(alphV, tauSR531)
plt.plot(alphV, tauSR532)
plt.plot(alphV, tauSR533)



plt.plot(alphV, np.ones_like(alphV) * 4e6, "k", ls="--")
plt.plot(alphV, np.ones_like(alphV) * 4e6 / 180, "k", ls="--")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-4, 1e12])
plt.xlim([0.034, 1])
plt.xlabel(r"$\alpha$",fontsize=25)
plt.ylabel(r"$\tau$",fontsize=25)
# Out:
# Text(0, 0.5, '$\\tau$')

# %%
M = 22.2
# mu = 1e-12
# alph = mu * M * GNew
alphV = np.logspace(np.log10(0.03), 0, 50)
mu = alphV / (GNew * M)


loadSR = np.loadtxt("test_store/541_new_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR541 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

loadSR = np.loadtxt("test_store/542_new_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR542 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

loadSR = np.loadtxt("test_store/543_new_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR543 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

loadSR = np.loadtxt("test_store/544_new_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR544 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

plt.plot(alphV, tauSR541)
#plt.plot(alphV, tauSR542)
plt.plot(alphV, tauSR543)
plt.plot(alphV, tauSR544)



plt.plot(alphV, np.ones_like(alphV) * 4e6, "k", ls="--")
plt.plot(alphV, np.ones_like(alphV) * 4e6 / 180, "k", ls="--")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-4, 1e20])
plt.xlim([0.034, 1])
plt.xlabel(r"$\alpha$",fontsize=25)
plt.ylabel(r"$\tau$",fontsize=25)
# Out:
# Text(0, 0.5, '$\\tau$')

# %%
M = 22.2
fa = 1e18
a = 0.9
alphV = np.logspace(np.log10(0.03), 0, 50)
mu = alphV / (GNew * M)

epsilon_211MAX = 1024 * np.pi * (fa / Mp)**2 / (9 * alphV**3)
# epsilon_3MAX = epsilon_211MAX *  (3 / 2)**4
epsilon_211MAX[epsilon_211MAX > 0.07] = 0.07 
epsilon_322MAX = epsilon_211MAX * 1e-1

    
loadSR = np.loadtxt("test_store/422_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR322 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

plt.plot(alphV, tauSR322)


# 211 x 211 -> 422 x BH
tau211BH = (1.5e-7 * alphV**11 * mu * (Mp / fa)**4 * (1 + np.sqrt(1 - a**2)) * epsilon_211MAX * epsilon_211MAX / hbar * 3.15e7)**(-1)
# 422 x 322 -> 211 x inf
tau322Inf = (1.6e-8 * alphV**8 * mu * (Mp / fa)**4  * epsilon_322MAX * epsilon_211MAX / hbar * 3.15e7)**(-1)
plt.plot(alphV, tau211BH)
plt.plot(alphV, tau322Inf)

fa = 1e16
# 211 x 211 -> 422 x BH
tau211BH = (1.5e-7 * alphV**11 * mu * (Mp / fa)**4 * (1 + np.sqrt(1 - a**2)) * epsilon_211MAX * epsilon_211MAX / hbar * 3.15e7)**(-1)
# 422 x 322 -> 211 x inf
tau322Inf = (1.6e-8 * alphV**8 * mu * (Mp / fa)**4  * epsilon_211MAX * epsilon_322MAX / hbar * 3.15e7)**(-1)
plt.plot(alphV, tau211BH, ls="--")
plt.plot(alphV, tau322Inf, ls="--")


plt.plot(alphV, np.ones_like(alphV) * 4e6, "k", ls="--")
plt.plot(alphV, np.ones_like(alphV) * 4e6 / 200, "k", ls="--")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-8, 1e8])
plt.xlim([0.034, 1])
plt.xlabel(r"$\alpha$",fontsize=25)
plt.ylabel(r"$\tau$",fontsize=25)
# Out:
# Text(0, 0.5, '$\\tau$')

# %%
M = 22.2
fa = 1e12
a = 0.9
alphV = np.logspace(np.log10(0.03), 0, 50)
mu = alphV / (GNew * M)

epsilon_211MAX = 1024 * np.pi * (fa / Mp)**2 / (9 * alphV**3)
# epsilon_3MAX = epsilon_211MAX *  (3 / 2)**4
epsilon_211MAX[epsilon_211MAX > 0.07] = 0.07 
epsilon_322MAX = epsilon_211MAX * 1e-1

    
loadSR = np.loadtxt("test_store/432_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)

tauSR322 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years

plt.plot(alphV, tauSR322)


# 211 x 211 -> 422 x BH
tau211BH = (1.5e-7 * alphV**11 * mu * (Mp / fa)**4 * (1 + np.sqrt(1 - a**2)) * epsilon_211MAX * epsilon_211MAX / hbar * 3.15e7)**(-1)
# 422 x 322 -> 211 x inf
tau322Inf = (1.2e-9 * alphV**8 * mu * (Mp / fa)**4  * 1e-2* 1e-2* epsilon_322MAX * epsilon_211MAX / hbar * 3.15e7)**(-1)
# plt.plot(alphV, tau211BH)
plt.plot(alphV, tau322Inf)
# 432 432 211 inf
tau322Inf = (4e-11 * alphV**8 * mu * (Mp / fa)**4  * 1e-19 * (epsilon_211MAX * 1e-2) / hbar * 3.15e7)**(-1)
plt.plot(alphV, tau322Inf)



plt.plot(alphV, np.ones_like(alphV) * 5e6, "k", ls="--")
plt.plot(alphV, np.ones_like(alphV) * 5e6 / 200, "k", ls="--")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-8, 1e15])
plt.xlim([0.034, 1])
plt.xlabel(r"$\alpha$",fontsize=25)
plt.ylabel(r"$\tau$",fontsize=25)
# Out:
# Text(0, 0.5, '$\\tau$')

# %%
M = 22.2
fa = 1e12
a = 0.9
alphV = np.logspace(np.log10(0.03), 0, 50)
mu = alphV / (GNew * M)

epsilon_211MAX = 1024 * np.pi * (fa / Mp)**2 / (9 * alphV**3)
# epsilon_3MAX = epsilon_211MAX *  (3 / 2)**4
epsilon_211MAX[epsilon_211MAX > 0.07] = 0.07 
epsilon_322MAX = epsilon_211MAX * 1e-1

    
loadSR = np.loadtxt("test_store/533_det_spin_0.9_test.dat")
int1 = interp1d(np.log10(loadSR[:,0]), np.log10(loadSR[:,1]), fill_value=-100, bounds_error=False)
tauSR322 = (10**int1(np.log10(alphV)) / (GNew * M) * mu / hbar * 3.15e7)**(-1)  # years
plt.plot(alphV, tauSR322)




plt.plot(alphV, np.ones_like(alphV) * 5e6, "k", ls="--")
plt.plot(alphV, np.ones_like(alphV) * 5e6 / 200, "k", ls="--")

plt.yscale("log")
plt.xscale("log")
plt.ylim([1e-8, 1e15])
plt.xlim([0.034, 1])
plt.xlabel(r"$\alpha$",fontsize=25)
plt.ylabel(r"$\tau$",fontsize=25)
# Out:
# Text(0, 0.5, '$\\tau$')
